# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the Jupyter Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this Jupyter notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Write your Algorithm
# * [Step 6](#step6): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# Make sure that you've downloaded the required human and dog datasets:
# * Download the [dog dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip).  Unzip the folder and place it in this project's home directory, at the location `/dogImages`.
#
# * Download the [human dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/lfw.zip).  Unzip the folder and place it in the home directory, at location `/lfw`.
#
# *Note: If you are using a Windows machine, you are encouraged to use [7zip](http://www.7-zip.org/) to extract the folder.*
#
# In the code cell below, we save the file paths for both the human (LFW) dataset and dog dataset in the numpy arrays `human_files` and `dog_files`.

# %%
import numpy as np
from glob import glob

# load filenames for human and dog images
human_files = np.array(glob("lfw/*/*"))
dog_files = np.array(glob("dogImages/*/*/*"))

# print number of images in each dataset
print('There are %d total human images.' % len(human_files))
print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 13233 total human images.
# There are 8351 total dog images.

# %%
#View the sample human photos.
import random
from PIL import Image
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

for img in random.sample(list(human_files), 2): 
#open and display input image
    image = Image.open(img) #img_path
    plt.imshow(image)
    plt.show()

# %%
#View the sample dog photos.
for img in random.sample(list(dog_files), 2): 
#open and display input image
    image = Image.open(img) #img_path
    plt.imshow(image)
    plt.show()

# %%
def filtered_images(image_path):
    mono_images=[]
    non_mono_images=[]
    for filename in image_path:
        try:
            img=Image.open(filename)
            #check pixel distribution
            v=img.histogram()
            h,w=img.size
            percentage_monochrome=max(v)/float(h*w)
            # filter bad and small images
            if percentage_monochrome>0.5 :#or h<300 or w<300:
                mono_images.append(filename)
            else:
                non_mono_images.append(filename)
        except:
            pass
    print("Number of monochrome images: {}\n".format(len(mono_images)))
    print("Number of non-monochrome images: {}\n".format(len(non_mono_images)))
    return mono_images, non_mono_images

# %%
g,b=filtered_images(dog_files)
# Out:
# Number of monochrome images: 85
#
# Number of non-monochrome images: 8266

# %% [markdown]
# # Create image frequency distribution for each dog class

# %%
import os
from pandas import DataFrame
entries = os.listdir('dogImages/train')
df = DataFrame (entries,columns=['dogbreed'])
df['frequency']=0
df
# Out:
#                             dogbreed  frequency
# 0                  001.Affenpinscher          0
# 1                   002.Afghan_hound          0
# 2               003.Airedale_terrier          0
# 3                          004.Akita          0
# 4               005.Alaskan_malamute          0
# ..                               ...        ...
# 128              129.Tibetan_mastiff          0
# 129       130.Welsh_springer_spaniel          0
# 130  131.Wirehaired_pointing_griffon          0
# 131               132.Xoloitzcuintli          0
# 132            133.Yorkshire_terrier          0
#
# [133 rows x 2 columns]

# %%
humanlist=os.listdir('lfw')
dfhuman=DataFrame(humanlist,columns=['names'])
dfhuman['freq']=0
dfhuman
# Out:
#                    names  freq
# 0              .DS_Store     0
# 1          Aaron_Eckhart     0
# 2            Aaron_Guiel     0
# 3        Aaron_Patterson     0
# 4          Aaron_Peirsol     0
# ...                  ...   ...
# 5745      Zorica_Radovic     0
# 5746      Zulfiqar_Ahmed     0
# 5747        Zumrati_Juma     0
# 5748     Zurab_Tsereteli     0
# 5749  Zydrunas_Ilgauskas     0
#
# [5750 rows x 2 columns]

# %% [markdown]
# Test to assign class with 1 frequency.

# %%
for files in dog_files:
    if files
df['frequency']['005.Alaskan_malamute']=1
df
# Out:
#                             dogbreed  frequency
# 0                  001.Affenpinscher          0
# 1                   002.Afghan_hound          0
# 2               003.Airedale_terrier          0
# 3                          004.Akita          1
# 4               005.Alaskan_malamute          0
# ..                               ...        ...
# 128              129.Tibetan_mastiff          0
# 129       130.Welsh_springer_spaniel          0
# 130  131.Wirehaired_pointing_griffon          0
# 131               132.Xoloitzcuintli          0
# 132            133.Yorkshire_terrier          0
#
# [133 rows x 2 columns]

# %% [markdown]
# Generate loop to find folders, following loop to find the subfolders.

# %%
def images_perfolder(main_path):
    main_folders=glob(main_path)
    dist_dict={}
    dist_df=pd.DataFrame()
    for fold in main_folders:
        folder_nm=os.path.basename(os.path.normpath(fold))
        print("# of images in",fold,":",len(glob(os.path.join(fold,"*","*"))))
        sub_folders=glob(os.path.join(fold,"*"))
        for breed_fold in sub_folders:
            breed_name=os.path.basename(os.path.normpath(breed_fold))
            dist_dict[breed_name]=len(glob(os.path.join(breed_fold,'*')))
            
        fold_df=pd.DataFrame.from_dict(dist_dict,orient='index').reset_index()
        fold_df['folder']=folder_nm
        dist_df=pd.concat([dist_df,fold_df],axis=0,ignore_index=True, sort=False)
    dist_df.rename(columns={0:'num_images','index':'category'},inplace=True)
    print(dist_df.groupby('folder')['num_images'].sum())
    return dist_df

# %%
dog_dist_df=images_perfolder('dogImages/*/')
dog_dist_df
# Out:
# # of images in dogImages\test\ : 836
# # of images in dogImages\train\ : 6680
# # of images in dogImages\valid\ : 835
# folder
# test      836
# train    6680
# valid     835
# Name: num_images, dtype: int64
#                             category  num_images folder
# 0                  001.Affenpinscher           8   test
# 1                   002.Afghan_hound           8   test
# 2               003.Airedale_terrier           6   test
# 3                          004.Akita           8   test
# 4               005.Alaskan_malamute          10   test
# ..                               ...         ...    ...
# 394              129.Tibetan_mastiff           6  valid
# 395       130.Welsh_springer_spaniel           6  valid
# 396  131.Wirehaired_pointing_griffon           4  valid
# 397               132.Xoloitzcuintli           4  valid
# 398            133.Yorkshire_terrier           4  valid
#
# [399 rows x 3 columns]

# %%
totalbybreed=dog_dist_df.groupby("category").num_images.sum() 
print(totalbybreed)
totalbybreed.hist()
# Out:
# category
# 001.Affenpinscher                  80
# 002.Afghan_hound                   73
# 003.Airedale_terrier               65
# 004.Akita                          79
# 005.Alaskan_malamute               96
#                                    ..
# 129.Tibetan_mastiff                60
# 130.Welsh_springer_spaniel         55
# 131.Wirehaired_pointing_griffon    37
# 132.Xoloitzcuintli                 33
# 133.Yorkshire_terrier              38
# Name: num_images, Length: 133, dtype: int64

# %%
totalbybreed.plot(kind="bar")

# %%
totalbybreed.describe()
# Out:
# count    133.000000
# mean      62.789474
# std       14.852330
# min       33.000000
# 25%       53.000000
# 50%       62.000000
# 75%       76.000000
# max       96.000000
# Name: num_images, dtype: float64

# %%
def images_perfolderhuman(main_path):
    main_folders=glob(main_path)
    dist_dict={}
    dist_df=pd.DataFrame()
    for fold in main_folders:
        folder_nm=os.path.basename(os.path.normpath(fold))
  #      print("# of images in",fold,":",len(glob(os.path.join(fold,"*"))))
        dist_dict[folder_nm]=len(glob(os.path.join(fold,'*')))
            
        fold_df=pd.DataFrame.from_dict(dist_dict,orient='index').reset_index()
        fold_df['folder']=folder_nm
        dist_df=pd.concat([dist_df,fold_df],axis=0,ignore_index=True, sort=False)
 #   dist_df.rename(columns={0:'num_images','index':'category'},inplace=True)
#     print(dist_df.groupby('folder')['num_images'].sum())
    return dist_df

# %%
main_folders=glob('lfw/*/')
dist_dict={}
dist_df=pd.DataFrame()
for fold in main_folders:
    folder_nm=os.path.basename(os.path.normpath(fold))
    print("# of images in",fold,":",len(glob(os.path.join(fold,"*"))))
    dist_dict[folder_nm]=len(glob(os.path.join(fold,'*')))

    fold_df=pd.DataFrame.from_dict(dist_dict,orient='index').reset_index()
    fold_df['folder']=folder_nm
    dist_df=pd.concat([dist_df,fold_df],axis=0,ignore_index=True, sort=False)
dist_df.rename(columns={0:'num_images','index':'category'},inplace=True)
print(dist_df.groupby('folder')['num_images'].sum())
# Out:
# # of images in lfw\Aaron_Eckhart\ : 1
# # of images in lfw\Aaron_Guiel\ : 1
# # of images in lfw\Aaron_Patterson\ : 1
# # of images in lfw\Aaron_Peirsol\ : 4
# # of images in lfw\Aaron_Pena\ : 1
# # of images in lfw\Aaron_Sorkin\ : 2
# # of images in lfw\Aaron_Tippin\ : 1
# # of images in lfw\Abbas_Kiarostami\ : 1
# # of images in lfw\Abba_Eban\ : 1
# # of images in lfw\Abdel_Aziz_Al-Hakim\ : 1
# # of images in lfw\Abdel_Madi_Shabneh\ : 1
# # of images in lfw\Abdel_Nasser_Assidi\ : 2
# # of images in lfw\Abdoulaye_Wade\ : 4
# # of images in lfw\Abdulaziz_Kamilov\ : 1
# # of images in lfw\Abdullah\ : 4
# # of images in lfw\Abdullah_Ahmad_Badawi\ : 1
# # of images in lfw\Abdullah_al-Attiyah\ : 3
# # of images in lfw\Abdullah_Gul\ : 19
# # of images in lfw\Abdullah_Nasseef\ : 1
# # of images in lfw\Abdullatif_Sener\ : 2
# # of images in lfw\Abdul_Majeed_Shobokshi\ : 1
# # of images in lfw\Abdul_Rahman\ : 1
# # of images in lfw\Abel_Aguilar\ : 1
# # of images in lfw\Abel_Pacheco\ : 4
# # of images in lfw\Abid_Hamid_Mahmud_Al-Tikriti\ : 3
# # of images in lfw\Abner_Martinez\ : 1
# # of images in lfw\Abraham_Foxman\ : 1
# # of images in lfw\Aby_Har-Even\ : 1
# # of images in lfw\Adam_Ant\ : 1
# # of images in lfw\Adam_Freier\ : 1
# # of images in lfw\Adam_Herbert\ : 1
# # of images in lfw\Adam_Kennedy\ : 1
# # of images in lfw\Adam_Mair\ : 1
# # of images in lfw\Adam_Rich\ : 1
# # of images in lfw\Adam_Sandler\ : 4
# # of images in lfw\Adam_Scott\ : 2
# # of images in lfw\Adelina_Avila\ : 1
# # of images in lfw\Adel_Al-Jubeir\ : 3
# # of images in lfw\Adisai_Bodharamik\ : 1
# # of images in lfw\Adolfo_Aguilar_Zinser\ : 3
# # of images in lfw\Adolfo_Rodriguez_Saa\ : 2
# # of images in lfw\Adoor_Gopalakarishnan\ : 1
# # of images in lfw\Adriana_Lima\ : 1
# # of images in lfw\Adriana_Perez_Navarro\ : 1
# # of images in lfw\Adrianna_Zuzic\ : 1
# # of images in lfw\Adrian_Annus\ : 1
# # of images in lfw\Adrian_Fernandez\ : 1
# # of images in lfw\Adrian_McPherson\ : 2
# # of images in lfw\Adrian_Murrell\ : 1
# # of images in lfw\Adrian_Nastase\ : 2
# # of images in lfw\Adrien_Brody\ : 12
# # of images in lfw\Afton_Smith\ : 1
# # of images in lfw\Agbani_Darego\ : 1
# # of images in lfw\Agnelo_Queiroz\ : 1
# # of images in lfw\Agnes_Bruckner\ : 1
# # of images in lfw\Ahmad_Jbarah\ : 1
# # of images in lfw\Ahmad_Masood\ : 2
# # of images in lfw\Ahmed_Ahmed\ : 1
# # of images in lfw\Ahmed_Chalabi\ : 5
# # of images in lfw\Ahmed_Ghazi\ : 1
# # of images in lfw\Ahmed_Ibrahim_Bilal\ : 1
# # of images in lfw\Ahmed_Lopez\ : 1
# # of images in lfw\Ahmed_Qureia\ : 1
# # of images in lfw\Ahmet_Demir\ : 1
# # of images in lfw\Ahmet_Necdet_Sezer\ : 2
# # of images in lfw\Aicha_El_Ouafi\ : 3
# # of images in lfw\Aidan_Quinn\ : 1
# # of images in lfw\Aileen_Riggin_Soule\ : 1
# # of images in lfw\Ainsworth_Dyer\ : 1
# # of images in lfw\Ain_Seppik\ : 1
# # of images in lfw\Aishwarya_Rai\ : 1
# # of images in lfw\Aitor_Gonzalez\ : 2
# # of images in lfw\Aiysha_Smith\ : 1
# # of images in lfw\Ai_Sugiyama\ : 5
# # of images in lfw\Ajit_Agarkar\ : 1
# # of images in lfw\AJ_Cook\ : 1
# # of images in lfw\AJ_Lamas\ : 1
# # of images in lfw\Akbar_Al_Baker\ : 1
# # of images in lfw\Akbar_Hashemi_Rafsanjani\ : 3
# # of images in lfw\Akhmed_Zakayev\ : 3
# # of images in lfw\Akiko_Morigami\ : 1
# # of images in lfw\Akmal_Taher\ : 1
# # of images in lfw\Alain_Cervantes\ : 1
# # of images in lfw\Alain_Ducasse\ : 1
# # of images in lfw\Alanis_Morissette\ : 1
# # of images in lfw\Alanna_Ubach\ : 1
# # of images in lfw\Alan_Ball\ : 2
# # of images in lfw\Alan_Dershowitz\ : 1
# # of images in lfw\Alan_Dreher\ : 1
# # of images in lfw\Alan_Greenspan\ : 5
# # of images in lfw\Alan_Greer\ : 1
# # of images in lfw\Alan_Jackson\ : 1
# # of images in lfw\Alan_Mulally\ : 2
# # of images in lfw\Alan_Stonecipher\ : 1
# # of images in lfw\Alan_Tang_Kwong-wing\ : 1
# # of images in lfw\Alan_Trammell\ : 1
# # of images in lfw\Alan_Zemaitis\ : 1
# # of images in lfw\Alastair_Campbell\ : 5
# # of images in lfw\Alastair_Johnston\ : 1
# # of images in lfw\Albaro_Recoba\ : 1
# # of images in lfw\Alberta_Lee\ : 1
# # of images in lfw\Alberto_Acosta\ : 1
# # of images in lfw\Alberto_Fujimori\ : 2
# # of images in lfw\Alberto_Gonzales\ : 1
# # of images in lfw\Alberto_Ruiz_Gallardon\ : 2
# # of images in lfw\Alberto_Sordi\ : 1
# # of images in lfw\Albert_Brooks\ : 1
# # of images in lfw\Albert_Costa\ : 6
# # of images in lfw\Albert_Montanes\ : 1
# # of images in lfw\Albert_Pujols\ : 1
# # of images in lfw\Albrecht_Mentz\ : 2
# # of images in lfw\Aldo_Paredes\ : 2
# # of images in lfw\Alecos_Markides\ : 1
# # of images in lfw\Alec_Baldwin\ : 4
# # of images in lfw\Alejandro_Atchugarry\ : 2
# # of images in lfw\Alejandro_Avila\ : 3
# # of images in lfw\Alejandro_Fernandez\ : 1
# # of images in lfw\Alejandro_Gonzalez_Inarritu\ : 1
# # of images in lfw\Alejandro_Lembo\ : 1
# # of images in lfw\Alejandro_Lerner\ : 1
# # of images in lfw\Alejandro_Lopez\ : 1
# # of images in lfw\Alejandro_Toledo\ : 39
# # of images in lfw\Aleksander_Kwasniewski\ : 4
# # of images in lfw\Aleksander_Voloshin\ : 1
# # of images in lfw\Alek_Wek\ : 1
# # of images in lfw\Alessandra_Cerna\ : 1
# # of images in lfw\Alessandro_Nesta\ : 1
# # of images in lfw\Alexander_Downer\ : 4
# # of images in lfw\Alexander_Losyukov\ : 4
# # of images in lfw\Alexander_Lukashenko\ : 1
# # of images in lfw\Alexander_Payne\ : 1
# # of images in lfw\Alexander_Rumyantsev\ : 2
# # of images in lfw\Alexandra_Jackson\ : 1
# # of images in lfw\Alexandra_Pelosi\ : 1
# # of images in lfw\Alexandra_Rozovskaya\ : 1
# # of images in lfw\Alexandra_Spann\ : 1
# # of images in lfw\Alexandra_Stevenson\ : 3
# # of images in lfw\Alexandra_Vodjanikova\ : 2
# # of images in lfw\Alexandre_Daigle\ : 1
# # of images in lfw\Alexandre_Despatie\ : 1
# # of images in lfw\Alexandre_Herchcovitch\ : 1
# # of images in lfw\Alexandre_Vinokourov\ : 1
# # of images in lfw\Alexa_Loren\ : 1
# # of images in lfw\Alexa_Vega\ : 1
# # of images in lfw\Alexis_Bledel\ : 1
# # of images in lfw\Alexis_Dennisoff\ : 1
# # of images in lfw\Alex_Barros\ : 2
# # of images in lfw\Alex_Cabrera\ : 1
# # of images in lfw\Alex_Cejka\ : 1
# # of images in lfw\Alex_Corretja\ : 1
# # of images in lfw\Alex_Ferguson\ : 1
# # of images in lfw\Alex_Gonzalez\ : 1
# # of images in lfw\Alex_Holmes\ : 1
# # of images in lfw\Alex_King\ : 1
# # of images in lfw\Alex_Penelas\ : 2
# # of images in lfw\Alex_Popov\ : 1
# # of images in lfw\Alex_Sink\ : 3
# # of images in lfw\Alex_Wallau\ : 1
# # of images in lfw\Alex_Zanardi\ : 1
# # of images in lfw\Alfonso_Cuaron\ : 1
# # of images in lfw\Alfonso_Portillo\ : 1
# # of images in lfw\Alfonso_Soriano\ : 1
# # of images in lfw\Alfredo_di_Stefano\ : 1
# # of images in lfw\Alfredo_Moreno\ : 1
# # of images in lfw\Alfredo_Pena\ : 1
# # of images in lfw\Alfred_Ford\ : 1
# # of images in lfw\Alfred_Sant\ : 1
# # of images in lfw\Alice_Fisher\ : 2
# # of images in lfw\Alicia_Hollowell\ : 1
# # of images in lfw\Alicia_Keys\ : 1
# # of images in lfw\Alicia_Molik\ : 1
# # of images in lfw\Alicia_Silverstone\ : 2
# # of images in lfw\Alicia_Witt\ : 1
# # of images in lfw\Alimzhan_Tokhtakhounov\ : 2
# # of images in lfw\Alina_Kabaeva\ : 1
# # of images in lfw\Aline_Chretien\ : 1
# # of images in lfw\Alisha_Richman\ : 1
# # of images in lfw\Alison_Krauss\ : 1
# # of images in lfw\Alison_Lohman\ : 2
# # of images in lfw\Alistair_MacDonald\ : 1
# # of images in lfw\Ali_Abbas\ : 2
# # of images in lfw\Ali_Abdullah_Saleh\ : 1
# # of images in lfw\Ali_Adbul_Karim_Madani\ : 1
# # of images in lfw\Ali_Ahmeti\ : 1
# # of images in lfw\Ali_Bin_Hussein\ : 1
# # of images in lfw\Ali_Fallahian\ : 1
# # of images in lfw\Ali_Hammoud\ : 1
# # of images in lfw\Ali_Khamenei\ : 3
# # of images in lfw\Ali_Mohammed_Maher\ : 1
# # of images in lfw\Ali_Naimi\ : 8
# # of images in lfw\Allan_Houston\ : 1
# # of images in lfw\Allan_Kemakeza\ : 1
# # of images in lfw\Allan_Wagner\ : 1
# # of images in lfw\Allen_Iverson\ : 2
# # of images in lfw\Allen_Rock\ : 1
# # of images in lfw\Allison_Janney\ : 2
# # of images in lfw\Allison_Searing\ : 1
# # of images in lfw\Allyson_Felix\ : 5
# # of images in lfw\Ally_Sheedy\ : 1
# # of images in lfw\Alma_Powell\ : 1
# # of images in lfw\Almeida_Baptista\ : 1
# # of images in lfw\Alonzo_Mourning\ : 1
# # of images in lfw\Alvaro_Noboa\ : 3
# # of images in lfw\Alvaro_Silva_Calderon\ : 4
# # of images in lfw\Alvaro_Uribe\ : 35
# # of images in lfw\Alyse_Beaupre\ : 1
# # of images in lfw\Alyson_Hannigan\ : 1
# # of images in lfw\Aly_Wagner\ : 1
# # of images in lfw\Al_Cardenas\ : 1
# # of images in lfw\Al_Davis\ : 2
# # of images in lfw\Al_Gore\ : 8
# # of images in lfw\Al_Leiter\ : 1
# # of images in lfw\Al_Pacino\ : 3
# # of images in lfw\Al_Sharpton\ : 7
# # of images in lfw\Amanda_Beard\ : 2
# # of images in lfw\Amanda_Bynes\ : 4
# # of images in lfw\Amanda_Coetzer\ : 2
# # of images in lfw\Amanda_Marsh\ : 1
# # of images in lfw\Amanda_Plumer\ : 1
# # of images in lfw\Amber_Frey\ : 1
# # of images in lfw\Amber_Tamblyn\ : 2
# # of images in lfw\Ambrose_Lee\ : 1
# # of images in lfw\Amelia_Vega\ : 7
# # of images in lfw\Amelie_Mauresmo\ : 21
# # of images in lfw\Amer_al-Saadi\ : 4
# # of images in lfw\Amporn_Falise\ : 1
# # of images in lfw\Amram_Mitzna\ : 2
# # of images in lfw\Amr_Moussa\ : 1
# # of images in lfw\Amy_Brenneman\ : 1
# # of images in lfw\Amy_Cotton\ : 1
# # of images in lfw\Amy_Gale\ : 1
# # of images in lfw\Amy_Pascal\ : 1
# # of images in lfw\Amy_Redford\ : 1
# # of images in lfw\Amy_Smart\ : 1
# # of images in lfw\Amy_Yasbeck\ : 1
# # of images in lfw\Anastasia_Kelesidou\ : 1
# # of images in lfw\Anastasia_Myskina\ : 3
# # of images in lfw\Anatoliy_Kinakh\ : 1
# # of images in lfw\Ana_Claudia_Talancon\ : 1
# # of images in lfw\Ana_Guevara\ : 7
# # of images in lfw\Ana_Isabel_Sanchez\ : 1
# # of images in lfw\Ana_Palacio\ : 8
# # of images in lfw\Ana_Paula_Gerard\ : 1
# # of images in lfw\Ana_Sebastiao\ : 1
# # of images in lfw\Anderson_Varejao\ : 1
# # of images in lfw\Anders_Ebbeson\ : 3
# # of images in lfw\Anders_Fogh_Rasmussen\ : 4
# # of images in lfw\Andreas_Vinciguerra\ : 1
# # of images in lfw\Andrea_Bocelli\ : 1
# # of images in lfw\Andrea_De_Cruz\ : 1
# # of images in lfw\Andrea_Kiser\ : 1
# # of images in lfw\Andrea_Yates\ : 1
# # of images in lfw\Andrei_Konchalovsky\ : 1
# # of images in lfw\Andrei_Mikhnevich\ : 2
# # of images in lfw\Andrei_Nikolishin\ : 1
# # of images in lfw\Andres_DAlessandro\ : 1
# # of images in lfw\Andres_Manuel_Lopez_Obrador\ : 1
# # of images in lfw\Andres_Pastrana\ : 1
# # of images in lfw\Andrew_Bernard\ : 1
# # of images in lfw\Andrew_Bunner\ : 2
# # of images in lfw\Andrew_Caldecott\ : 1
# # of images in lfw\Andrew_Cuomo\ : 2
# # of images in lfw\Andrew_Fastow\ : 1
# # of images in lfw\Andrew_Firestone\ : 1
# # of images in lfw\Andrew_Gilligan\ : 1
# # of images in lfw\Andrew_Jarecki\ : 1
# # of images in lfw\Andrew_Luster\ : 1
# # of images in lfw\Andrew_Niccol\ : 2
# # of images in lfw\Andrew_Sabey\ : 1
# # of images in lfw\Andrew_Shutley\ : 1
# # of images in lfw\Andrew_Weissmann\ : 3
# # of images in lfw\Andrew_Wetzler\ : 1
# # of images in lfw\Andre_Agassi\ : 36
# # of images in lfw\Andre_Bucher\ : 1
# # of images in lfw\Andre_Lange\ : 1
# # of images in lfw\Andre_Smith\ : 1
# # of images in lfw\Andre_Techine\ : 1
# # of images in lfw\Andrzej_Tyszkiewicz\ : 1
# # of images in lfw\Andy_Benes\ : 1
# # of images in lfw\Andy_Bryant\ : 1
# # of images in lfw\Andy_Dick\ : 1
# # of images in lfw\Andy_Garcia\ : 1
# # of images in lfw\Andy_Graves\ : 1
# # of images in lfw\Andy_Griffith\ : 1
# # of images in lfw\Andy_Griggs\ : 1
# # of images in lfw\Andy_Hebb\ : 2
# # of images in lfw\Andy_Lau\ : 1
# # of images in lfw\Andy_Madikians\ : 1
# # of images in lfw\Andy_North\ : 1
# # of images in lfw\Andy_Perez\ : 1
# # of images in lfw\Andy_Roddick\ : 15
# # of images in lfw\Andy_Rooney\ : 1
# # of images in lfw\Andy_Warhol\ : 1
# # of images in lfw\Andy_Wisecarver\ : 1
# # of images in lfw\Anette_Hosoi\ : 1
# # of images in lfw\AnFernce_Negron\ : 1
# # of images in lfw\Angela_Alvarado_Rosa\ : 1
# # of images in lfw\Angela_Bassett\ : 6
# # of images in lfw\Angela_Lansbury\ : 2
# # of images in lfw\Angela_Mascia-Frye\ : 1
# # of images in lfw\Angela_Merkel\ : 5
# # of images in lfw\Angelica_Romero\ : 1
# # of images in lfw\Angelina_Jolie\ : 20
# # of images in lfw\Angelo_Genova\ : 1
# # of images in lfw\Angelo_Reyes\ : 4
# # of images in lfw\Angel_Lockward\ : 1
# # of images in lfw\Angel_Maza\ : 1
# # of images in lfw\Angie_Arzola\ : 1
# # of images in lfw\Angie_Martinez\ : 1
# # of images in lfw\Anibal_Ibarra\ : 3
# # of images in lfw\Anil_Ramsook\ : 1
# # of images in lfw\Anita_DeFrantz\ : 1
# # of images in lfw\Anja_Paerson\ : 1
# # of images in lfw\Anjum_Hussain\ : 1
# # of images in lfw\Anna_Chicherova\ : 1
# # of images in lfw\Anna_Faris\ : 1
# # of images in lfw\Anna_Jones\ : 1
# # of images in lfw\Anna_Kournikova\ : 12
# # of images in lfw\Anna_Nicole_Smith\ : 2
# # of images in lfw\Anneli_Jaatteenmaki\ : 2
# # of images in lfw\Annette_Bening\ : 2
# # of images in lfw\Annette_Lu\ : 3
# # of images in lfw\Anne_Cavers\ : 1
# # of images in lfw\Anne_Donovan\ : 1
# # of images in lfw\Anne_Heche\ : 1
# # of images in lfw\Anne_Krueger\ : 3
# # of images in lfw\Anne_McLellan\ : 3
# # of images in lfw\Anne_ONeil\ : 1
# # of images in lfw\Annie-Jeanne_Reynaud\ : 1
# # of images in lfw\Annie_Chaplin\ : 1
# # of images in lfw\Annie_Machon\ : 1
# # of images in lfw\Annika_Sorenstam\ : 1
# # of images in lfw\Ann_Godbehere\ : 1
# # of images in lfw\Ann_Landers\ : 1
# # of images in lfw\Ann_Morgan\ : 1
# # of images in lfw\Ann_Veneman\ : 11
# # of images in lfw\Antanas_Valionis\ : 1
# # of images in lfw\Anthony_Carter\ : 1
# # of images in lfw\Anthony_Corso\ : 1
# # of images in lfw\Anthony_Ervin\ : 1
# # of images in lfw\Anthony_Fauci\ : 2
# # of images in lfw\Anthony_Garotinho\ : 1
# # of images in lfw\Anthony_Hazen\ : 1
# # of images in lfw\Anthony_Hopkins\ : 2
# # of images in lfw\Anthony_LaPaglia\ : 2
# # of images in lfw\Anthony_Lee_Johnson\ : 1
# # of images in lfw\Anthony_Mazur\ : 1
# # of images in lfw\Anthony_Pico\ : 1
# # of images in lfw\Anthony_Pisciotti\ : 1
# # of images in lfw\Anthony_Principi\ : 1
# # of images in lfw\Anthony_Rackauckas\ : 1
# # of images in lfw\Anthony_Scott_Miller\ : 1
# # of images in lfw\Antje_Buschschulte\ : 1
# # of images in lfw\Antonio_Banderas\ : 5
# # of images in lfw\Antonio_Bernardo\ : 1
# # of images in lfw\Antonio_Cassano\ : 1
# # of images in lfw\Antonio_Catania\ : 1
# # of images in lfw\Antonio_Elias_Saca\ : 1
# # of images in lfw\Antonio_Palocci\ : 8
# # of images in lfw\Antonio_Trillanes\ : 3
# # of images in lfw\Antony_Leung\ : 4
# # of images in lfw\Anton_Balasingham\ : 1
# # of images in lfw\Antwun_Echols\ : 1
# # of images in lfw\Anwar_Ibrahim\ : 2
# # of images in lfw\Anzori_Kikalishvili\ : 1
# # of images in lfw\Aparna_Pillai\ : 1
# # of images in lfw\Aram_Adler\ : 1
# # of images in lfw\Arantxa_Sanchez-Vicario\ : 2
# # of images in lfw\Aretha_Franklin\ : 1
# # of images in lfw\Arianna_Huffington\ : 4
# # of images in lfw\Ariel_Sharon\ : 77
# # of images in lfw\Arie_Haan\ : 1
# # of images in lfw\Arif_Mardin\ : 1
# # of images in lfw\Ari_Bousbib\ : 1
# # of images in lfw\Ari_Fleischer\ : 13
# # of images in lfw\Arlen_Specter\ : 3
# # of images in lfw\Armando_Avila_Panchame\ : 1
# # of images in lfw\Armando_Calderon_Sol\ : 1
# # of images in lfw\Armando_Carrillo\ : 1
# # of images in lfw\Armand_Sargen\ : 1
# # of images in lfw\Arminio_Fraga\ : 6
# # of images in lfw\Arnaud_Clement\ : 2
# # of images in lfw\Arnaud_Lagardere\ : 1
# # of images in lfw\Arnie_Boehm\ : 1
# # of images in lfw\Arnoldo_Aleman\ : 5
# # of images in lfw\Arnold_Palmer\ : 3
# # of images in lfw\Arnold_Schwarzenegger\ : 42
# # of images in lfw\Arnold_Scott\ : 1
# # of images in lfw\Aron_Ralston\ : 2
# # of images in lfw\Arsinee_Khanjian\ : 2
# # of images in lfw\Arthur_Johnson\ : 1
# # of images in lfw\Arthur_Martinez\ : 1
# # of images in lfw\Artieas_Shanks\ : 1
# # of images in lfw\Arturo_Gatti\ : 3
# # of images in lfw\Art_Cooper\ : 1
# # of images in lfw\Art_Hoffmann\ : 2
# # of images in lfw\Art_Howe\ : 4
# # of images in lfw\Art_Lopez\ : 1
# # of images in lfw\Arye_Mekel\ : 2
# # of images in lfw\Asa_Hutchinson\ : 2
# # of images in lfw\Ascencion_Barajas\ : 1
# # of images in lfw\Ashanti\ : 5
# # of images in lfw\Ashlea_Talbot\ : 1
# # of images in lfw\Ashley_Judd\ : 1
# # of images in lfw\Ashley_Olsen\ : 1
# # of images in lfw\Ashley_Postell\ : 1
# # of images in lfw\Ashraf_Alasmar\ : 1
# # of images in lfw\Ashraf_Ghani\ : 1
# # of images in lfw\Ashton_Kutcher\ : 3
# # of images in lfw\Asif_Ali_Zardari\ : 1
# # of images in lfw\Asif_Hanif\ : 1
# # of images in lfw\Askar_Akayev\ : 1
# # of images in lfw\Asmaa_Assad\ : 1
# # of images in lfw\Assad_Ahmadi\ : 1
# # of images in lfw\Astou_Ndiaye-Diatta\ : 1
# # of images in lfw\Astrid_Betancourt\ : 1
# # of images in lfw\Astrid_Eyzaguirre\ : 1
# # of images in lfw\Atal_Bihari_Vajpayee\ : 24
# # of images in lfw\Ataollah_Mohajerani\ : 1
# # of images in lfw\Atiabet_Ijan_Amabel\ : 1
# # of images in lfw\Atom_Egoyan\ : 1
# # of images in lfw\Atsushi_Sato\ : 1
# # of images in lfw\Audrey_Lacroix\ : 1
# # of images in lfw\Audrey_Sauret\ : 1
# # of images in lfw\Augustin_Calleri\ : 4
# # of images in lfw\Augusto_Pinochet\ : 2
# # of images in lfw\Augusto_Roa_Bastos\ : 2
# # of images in lfw\Aung_San_Suu_Kyi\ : 2
# # of images in lfw\Austin_Kearns\ : 1
# # of images in lfw\Avril_Lavigne\ : 1
# # of images in lfw\Azmi_Bishara\ : 1
# # of images in lfw\Azra_Akin\ : 4
# # of images in lfw\Babe_Ruth\ : 1
# # of images in lfw\Baburam_Bhattari\ : 1
# # of images in lfw\Bak_Chang-Ryun\ : 1
# # of images in lfw\Barbara_Bach\ : 1
# # of images in lfw\Barbara_Becker\ : 1
# # of images in lfw\Barbara_Bodine\ : 1
# # of images in lfw\Barbara_Boxer\ : 1
# # of images in lfw\Barbara_Brezigar\ : 2
# # of images in lfw\Barbara_De_Brun\ : 1
# # of images in lfw\Barbara_Esbin\ : 1
# # of images in lfw\Barbara_Felt-Miller\ : 1
# # of images in lfw\Barbara_Roberts\ : 1
# # of images in lfw\Barbara_Walters\ : 4
# # of images in lfw\Barbora_Strycova\ : 1
# # of images in lfw\Barbra_Streisand\ : 3
# # of images in lfw\Barrett_Jackman\ : 2
# # of images in lfw\Barry_Alvarez\ : 2
# # of images in lfw\Barry_Bonds\ : 1
# # of images in lfw\Barry_Collier\ : 1
# # of images in lfw\Barry_Diller\ : 1
# # of images in lfw\Barry_Ford\ : 1
# # of images in lfw\Barry_Hinson\ : 1
# # of images in lfw\Barry_Nakell\ : 1
# # of images in lfw\Barry_Switzer\ : 1
# # of images in lfw\Barry_Williams\ : 1
# # of images in lfw\Barry_Zito\ : 2
# # of images in lfw\Bartosz_Kizierowski\ : 1
# # of images in lfw\Bart_Freundlich\ : 1
# # of images in lfw\Bart_Hendricks\ : 1
# # of images in lfw\Barzan_al-Tikriti\ : 1
# # of images in lfw\Basdeo_Panday\ : 1
# # of images in lfw\Bashar_Assad\ : 4
# # of images in lfw\Baz_Luhrmann\ : 1
# # of images in lfw\BB_King\ : 1
# # of images in lfw\Beatrice_Dalle\ : 1
# # of images in lfw\Beatriz_Merino\ : 1
# # of images in lfw\Beecher_Ray_Kirby\ : 1
# # of images in lfw\Begum_Khaleda_Zia\ : 2
# # of images in lfw\Bela_Karolyi\ : 1
# # of images in lfw\Benazir_Bhutto\ : 5
# # of images in lfw\Benedita_da_Silva\ : 1
# # of images in lfw\Benicio_Del_Toro\ : 1
# # of images in lfw\Benito_Santiago\ : 1
# # of images in lfw\Benjamin_Bratt\ : 1
# # of images in lfw\Benjamin_Franklin\ : 1
# # of images in lfw\Benjamin_Martinez\ : 1
# # of images in lfw\Benjamin_McKenzie\ : 1
# # of images in lfw\Benjamin_Netanyahu\ : 5
# # of images in lfw\Benjamin_Neulander\ : 1
# # of images in lfw\Ben_Affleck\ : 7
# # of images in lfw\Ben_Betts\ : 1
# # of images in lfw\Ben_Braun\ : 1
# # of images in lfw\Ben_Broussard\ : 1
# # of images in lfw\Ben_Cahoon\ : 1
# # of images in lfw\Ben_Chandler\ : 1
# # of images in lfw\Ben_Cohen\ : 1
# # of images in lfw\Ben_Curtis\ : 3
# # of images in lfw\Ben_Davis\ : 1
# # of images in lfw\Ben_Glisan\ : 2
# # of images in lfw\Ben_Howland\ : 4
# # of images in lfw\Ben_Kingsley\ : 1
# # of images in lfw\Ben_Lee\ : 1
# # of images in lfw\Ben_Stein\ : 1
# # of images in lfw\Ben_Wallace\ : 1
# # of images in lfw\Bernadette_Peters\ : 1
# # of images in lfw\Bernardo_Segura\ : 2
# # of images in lfw\Bernard_Ebbers\ : 1
# # of images in lfw\Bernard_Giraudeau\ : 1
# # of images in lfw\Bernard_Kerik\ : 1
# # of images in lfw\Bernard_Landry\ : 4
# # of images in lfw\Bernard_Law\ : 5
# # of images in lfw\Bernard_Lord\ : 2
# # of images in lfw\Bernard_Siegel\ : 1
# # of images in lfw\Bernice_Wong\ : 1
# # of images in lfw\Bertie_Ahern\ : 5
# # of images in lfw\Bertrand_Bonello\ : 2
# # of images in lfw\Bertrand_Delanoe\ : 1
# # of images in lfw\Beth_Blough\ : 1
# # of images in lfw\Beth_Jones\ : 2
# # of images in lfw\Betsy_Coffin\ : 1
# # of images in lfw\Betsy_Smith\ : 2
# # of images in lfw\Bettina_Rheims\ : 1
# # of images in lfw\Betty_Garrison\ : 1
# # of images in lfw\Betty_Williams\ : 1
# # of images in lfw\Beyonce_Knowles\ : 1
# # of images in lfw\Bianca_Jagger\ : 1
# # of images in lfw\Bijan_Darvish\ : 3
# # of images in lfw\Bijan_Namdar_Zangeneh\ : 2
# # of images in lfw\Bilal_Erdogan\ : 1
# # of images in lfw\Biljana_Plavsic\ : 3
# # of images in lfw\Billy_Andrade\ : 1
# # of images in lfw\Billy_Beane\ : 1
# # of images in lfw\Billy_Bob_Thornton\ : 1
# # of images in lfw\Billy_Boyd\ : 1
# # of images in lfw\Billy_Crawford\ : 1
# # of images in lfw\Billy_Crystal\ : 6
# # of images in lfw\Billy_Donovan\ : 1
# # of images in lfw\Billy_Edelin\ : 1
# # of images in lfw\Billy_Gilman\ : 1
# # of images in lfw\Billy_Graham\ : 2
# # of images in lfw\Billy_Joel\ : 1
# # of images in lfw\Billy_Rork\ : 1
# # of images in lfw\Billy_Sollie\ : 2
# # of images in lfw\Billy_Tibbets\ : 1
# # of images in lfw\Bill_Belichick\ : 2
# # of images in lfw\Bill_Bradley\ : 1
# # of images in lfw\Bill_Butler\ : 1
# # of images in lfw\Bill_Byrne\ : 1
# # of images in lfw\Bill_Callahan\ : 3
# # of images in lfw\Bill_Carmody\ : 1
# # of images in lfw\Bill_Cartwright\ : 1
# # of images in lfw\Bill_Clancy\ : 1
# # of images in lfw\Bill_Clinton\ : 29
# # of images in lfw\Bill_Curry\ : 1
# # of images in lfw\Bill_Doba\ : 1
# # of images in lfw\Bill_Duffey\ : 1
# # of images in lfw\Bill_Elliott\ : 1
# # of images in lfw\Bill_Fennelly\ : 1
# # of images in lfw\Bill_Frist\ : 9
# # of images in lfw\Bill_Gates\ : 17
# # of images in lfw\Bill_Graham\ : 9
# # of images in lfw\Bill_Guerin\ : 1
# # of images in lfw\Bill_Herrion\ : 1
# # of images in lfw\Bill_Hughes\ : 1
# # of images in lfw\Bill_King\ : 1
# # of images in lfw\Bill_Kollar\ : 1
# # of images in lfw\Bill_Kong\ : 1
# # of images in lfw\Bill_Lerach\ : 1
# # of images in lfw\Bill_Maher\ : 1
# # of images in lfw\Bill_Mauldin\ : 1
# # of images in lfw\Bill_McBride\ : 10
# # of images in lfw\Bill_Nelson\ : 2
# # of images in lfw\Bill_OReilly\ : 1
# # of images in lfw\Bill_Parcells\ : 2
# # of images in lfw\Bill_Parsons\ : 1
# # of images in lfw\Bill_Paxton\ : 4
# # of images in lfw\Bill_Pryor\ : 1
# # of images in lfw\Bill_Rainer\ : 1
# # of images in lfw\Bill_Readdy\ : 1
# # of images in lfw\Bill_Richardson\ : 1
# # of images in lfw\Bill_Self\ : 1
# # of images in lfw\Bill_Simon\ : 15
# # of images in lfw\Bill_Sizemore\ : 2
# # of images in lfw\Bill_Stapleton\ : 1
# # of images in lfw\Bill_Stein\ : 1
# # of images in lfw\Bill_Walton\ : 1
# # of images in lfw\Bing_Crosby\ : 1
# # of images in lfw\Binyamin_Ben-Eliezer\ : 7
# # of images in lfw\Bison_Dele\ : 1
# # of images in lfw\Bixente_LIzarazu\ : 1
# # of images in lfw\BJ_Habibie\ : 1
# # of images in lfw\Blas_Ople\ : 1
# # of images in lfw\Blythe_Danner\ : 2
# # of images in lfw\Blythe_Hartley\ : 2
# # of images in lfw\Bobby_Bowden\ : 1
# # of images in lfw\Bobby_Goldwater\ : 2
# # of images in lfw\Bobby_Jackson\ : 1
# # of images in lfw\Bobby_Kielty\ : 1
# # of images in lfw\Bobby_Robson\ : 2
# # of images in lfw\Bobo_Balde\ : 1
# # of images in lfw\Bob_Alper\ : 1
# # of images in lfw\Bob_Beauprez\ : 2
# # of images in lfw\Bob_Bowlsby\ : 1
# # of images in lfw\Bob_Cantrell\ : 1
# # of images in lfw\Bob_Colvin\ : 2
# # of images in lfw\Bob_Crippen\ : 1
# # of images in lfw\Bob_Curtis\ : 1
# # of images in lfw\Bob_Dole\ : 3
# # of images in lfw\Bob_Eskridge\ : 1
# # of images in lfw\Bob_Ferguson\ : 1
# # of images in lfw\Bob_Geldof\ : 2
# # of images in lfw\Bob_Goldman\ : 1
# # of images in lfw\Bob_Graham\ : 6
# # of images in lfw\Bob_Guccione\ : 1
# # of images in lfw\Bob_Hartley\ : 1
# # of images in lfw\Bob_Hayes\ : 1
# # of images in lfw\Bob_Herz\ : 1
# # of images in lfw\Bob_Holden\ : 1
# # of images in lfw\Bob_Hope\ : 8
# # of images in lfw\Bob_Huggins\ : 4
# # of images in lfw\Bob_Iger\ : 1
# # of images in lfw\Bob_Krueger\ : 1
# # of images in lfw\Bob_Melvin\ : 1
# # of images in lfw\Bob_Menendez\ : 1
# # of images in lfw\Bob_Newhart\ : 1
# # of images in lfw\Bob_Petrino\ : 1
# # of images in lfw\Bob_Riley\ : 1
# # of images in lfw\Bob_Stoops\ : 7
# # of images in lfw\Bob_Sulkin\ : 1
# # of images in lfw\Bob_Taft\ : 1
# # of images in lfw\Bob_Wright\ : 1
# # of images in lfw\Bode_Miller\ : 2
# # of images in lfw\Bonnie_Fuller\ : 1
# # of images in lfw\Bonnie_Hunt\ : 1
# # of images in lfw\Bono\ : 3
# # of images in lfw\Boris_Becker\ : 6
# # of images in lfw\Boris_Berezovsky\ : 2
# # of images in lfw\Boris_Henry\ : 1
# # of images in lfw\Boris_Jordan\ : 1
# # of images in lfw\Boris_Trajkovski\ : 1
# # of images in lfw\Boris_Yeltsin\ : 2
# # of images in lfw\Boutros_Boutros_Ghali\ : 1
# # of images in lfw\Bo_Pelini\ : 2
# # of images in lfw\Bo_Ryan\ : 2
# # of images in lfw\Brady_Rodgers\ : 1
# # of images in lfw\Brad_Alexander_Smith\ : 1
# # of images in lfw\Brad_Banks\ : 1
# # of images in lfw\Brad_Brownell\ : 1
# # of images in lfw\Brad_Garrett\ : 4
# # of images in lfw\Brad_Gushue\ : 1
# # of images in lfw\Brad_Johnson\ : 5
# # of images in lfw\Brad_Miller\ : 1
# # of images in lfw\Brad_Pitt\ : 1
# # of images in lfw\Brad_Russ\ : 1
# # of images in lfw\Brad_Smith\ : 1
# # of images in lfw\Brad_Wilk\ : 1
# # of images in lfw\Brajesh_Mishra\ : 1
# # of images in lfw\Brandon_Boyd\ : 1
# # of images in lfw\Brandon_Fails\ : 1
# # of images in lfw\Brandon_Hammond\ : 1
# # of images in lfw\Brandon_Inge\ : 1
# # of images in lfw\Brandon_Jones\ : 1
# # of images in lfw\Brandon_Knight\ : 1
# # of images in lfw\Brandon_Larson\ : 1
# # of images in lfw\Brandon_Lloyd\ : 1
# # of images in lfw\Brandon_Robinson\ : 1
# # of images in lfw\Brandon_Spann\ : 1
# # of images in lfw\Brandon_Webb\ : 1
# # of images in lfw\Branko_Crvenkovski\ : 3
# # of images in lfw\Brawley_King\ : 1
# # of images in lfw\Brendan_Fraser\ : 1
# # of images in lfw\Brendan_Gaughan\ : 1
# # of images in lfw\Brendan_Hansen\ : 2
# # of images in lfw\Brendan_Stai\ : 1
# # of images in lfw\Brenda_Magana\ : 1
# # of images in lfw\Brenda_van_Dam\ : 1
# # of images in lfw\Brenda_Wilson\ : 1
# # of images in lfw\Brennon_Leighton\ : 1
# # of images in lfw\Brent_Coles\ : 1
# # of images in lfw\Brett_Boone\ : 1
# # of images in lfw\Brett_Hawke\ : 1
# # of images in lfw\Brett_Hull\ : 1
# # of images in lfw\Brett_Perry\ : 1
# # of images in lfw\Brian_Billick\ : 1
# # of images in lfw\Brian_Campbell\ : 1
# # of images in lfw\Brian_Cashman\ : 1
# # of images in lfw\Brian_Clemens\ : 1
# # of images in lfw\Brian_Cook\ : 1
# # of images in lfw\Brian_Cowen\ : 2
# # of images in lfw\Brian_De_Palma\ : 1
# # of images in lfw\Brian_Florence\ : 1
# # of images in lfw\Brian_Grazier\ : 1
# # of images in lfw\Brian_Gregory\ : 1
# # of images in lfw\Brian_Griese\ : 2
# # of images in lfw\Brian_Heidik\ : 2
# # of images in lfw\Brian_Henson\ : 1
# # of images in lfw\Brian_Jordan\ : 1
# # of images in lfw\Brian_Kerr\ : 1
# # of images in lfw\Brian_Lara\ : 1
# # of images in lfw\Brian_McIntyre\ : 1
# # of images in lfw\Brian_Meadors\ : 1
# # of images in lfw\Brian_Mulroney\ : 2
# # of images in lfw\Brian_Olson\ : 1
# # of images in lfw\Brian_Pavlich\ : 1
# # of images in lfw\Brian_Scalabrine\ : 1
# # of images in lfw\Brian_Schneider\ : 1
# # of images in lfw\Brian_StPierre\ : 1
# # of images in lfw\Brian_Van_Dusen\ : 1
# # of images in lfw\Brian_Weaver\ : 1
# # of images in lfw\Brian_Wells\ : 2
# # of images in lfw\Brian_Williams\ : 1
# # of images in lfw\Bridgette_Wilson-Sampras\ : 3
# # of images in lfw\Bridget_Fonda\ : 3
# # of images in lfw\Brigitte_Boisselier\ : 2
# # of images in lfw\Britney_Spears\ : 14
# # of images in lfw\Brittany_Snow\ : 1
# # of images in lfw\Brock_Berlin\ : 1
# # of images in lfw\Bronson_Arroyo\ : 1
# # of images in lfw\Brooke_Adams\ : 1
# # of images in lfw\Brooke_Gordon\ : 1
# # of images in lfw\Brooke_Shields\ : 2
# # of images in lfw\Brook_Robinson\ : 1
# # of images in lfw\Bruce_Arena\ : 1
# # of images in lfw\Bruce_Gebhardt\ : 1
# # of images in lfw\Bruce_Lunsford\ : 1
# # of images in lfw\Bruce_Paltrow\ : 1
# # of images in lfw\Bruce_Springsteen\ : 4
# # of images in lfw\Bruce_Van_De_Velde\ : 2
# # of images in lfw\Bruce_Weber\ : 2
# # of images in lfw\Bruce_Willis\ : 1
# # of images in lfw\Bruna_Colosio\ : 1
# # of images in lfw\Bruno_Junquiera\ : 1
# # of images in lfw\Bryant_Young\ : 1
# # of images in lfw\Bryan_Adams\ : 1
# # of images in lfw\Bryan_Chui\ : 1
# # of images in lfw\Bryan_Cooley\ : 1
# # of images in lfw\Bryan_Murray\ : 1
# # of images in lfw\Bryan_Thomas\ : 1
# # of images in lfw\Bryce_Carmine\ : 1
# # of images in lfw\Buck_Rodgers\ : 1
# # of images in lfw\Buddy_Ryan\ : 1
# # of images in lfw\Budd_Schulberg\ : 1
# # of images in lfw\Bud_Selig\ : 4
# # of images in lfw\Buford_Blount\ : 1
# # of images in lfw\Bulent_Ecevit\ : 6
# # of images in lfw\Bustam_A_Zedan_Aljanabi\ : 1
# # of images in lfw\Butch_Davis\ : 2
# # of images in lfw\Buzz_Hargrove\ : 1
# # of images in lfw\Byron_Scott\ : 2
# # of images in lfw\Cabas\ : 1
# # of images in lfw\Caio_Blat\ : 1
# # of images in lfw\Calbert_Cheaney\ : 1
# # of images in lfw\Calista_Flockhart\ : 6
# # of images in lfw\Calvin_Harrison\ : 1
# # of images in lfw\Calvin_Joseph_Coleman\ : 1
# # of images in lfw\Cameron_Diaz\ : 6
# # of images in lfw\Camilla_Parker_Bowles\ : 2
# # of images in lfw\Camille_Colvin\ : 1
# # of images in lfw\Camille_Lewis\ : 1
# # of images in lfw\Camryn_Manheim\ : 1
# # of images in lfw\Candace_Sutton\ : 1
# # of images in lfw\Candice_Beatty\ : 1
# # of images in lfw\Candice_Bergen\ : 3
# # of images in lfw\Candie_Kung\ : 4
# # of images in lfw\Carey_Lowell\ : 1
# # of images in lfw\Carina_Lau_Ka-ling\ : 1
# # of images in lfw\Carin_Koch\ : 1
# # of images in lfw\Cari_Davis\ : 1
# # of images in lfw\Carla_Del_Ponte\ : 5
# # of images in lfw\Carla_Gay_Balingit\ : 1
# # of images in lfw\Carla_Gugino\ : 1
# # of images in lfw\Carla_Moreno\ : 1
# # of images in lfw\Carla_Myers\ : 2
# # of images in lfw\Carla_Sullivan\ : 1
# # of images in lfw\Carla_Tricoli\ : 1
# # of images in lfw\Carlos_Alberto\ : 1
# # of images in lfw\Carlos_Alberto_Parreira\ : 1
# # of images in lfw\Carlos_Arroyo\ : 1
# # of images in lfw\Carlos_Barra\ : 1
# # of images in lfw\Carlos_Barragan\ : 1
# # of images in lfw\Carlos_Beltran\ : 1
# # of images in lfw\Carlos_Bianchi\ : 2
# # of images in lfw\Carlos_De_Abreu\ : 1
# # of images in lfw\Carlos_Fasciolo\ : 1
# # of images in lfw\Carlos_Ghosn\ : 2
# # of images in lfw\Carlos_Iturgaitz\ : 1
# # of images in lfw\Carlos_Juarez\ : 1
# # of images in lfw\Carlos_Lordkipanitse\ : 1
# # of images in lfw\Carlos_Manuel_Pruneda\ : 3
# # of images in lfw\Carlos_Menem\ : 21
# # of images in lfw\Carlos_Mesa\ : 2
# # of images in lfw\Carlos_Moya\ : 19
# # of images in lfw\Carlos_Ortega\ : 3
# # of images in lfw\Carlos_Paternina\ : 1
# # of images in lfw\Carlos_Queiroz\ : 1
# # of images in lfw\Carlos_Quintanilla_Schmidt\ : 2
# # of images in lfw\Carlos_Ruckauf\ : 1
# # of images in lfw\Carlos_Ruiz\ : 3
# # of images in lfw\Carlos_Salinas\ : 1
# # of images in lfw\Carlos_Savedra\ : 1
# # of images in lfw\Carlos_Vives\ : 4
# # of images in lfw\Carlo_Ancelotti\ : 3
# # of images in lfw\Carlo_Azeglio_Ciampi\ : 1
# # of images in lfw\Carlton_Baugh\ : 1
# # of images in lfw\Carlton_Dotson\ : 1
# # of images in lfw\Carly_Fiorina\ : 3
# # of images in lfw\Carly_Gullickson\ : 1
# # of images in lfw\Carl_Levin\ : 1
# # of images in lfw\Carl_Pope\ : 1
# # of images in lfw\Carl_Reiner\ : 2
# # of images in lfw\Carmen_Electra\ : 6
# # of images in lfw\Carolina_Barco\ : 1
# # of images in lfw\Carolina_Kluft\ : 3
# # of images in lfw\Carolina_Moraes\ : 2
# # of images in lfw\Caroline_Dhavernas\ : 1
# # of images in lfw\Caroline_Kennedy\ : 3
# # of images in lfw\Caroline_Link\ : 1
# # of images in lfw\Carolyn_Dawn_Johnson\ : 3
# # of images in lfw\Carolyn_Kuhl\ : 1
# # of images in lfw\Carol_Burnett\ : 2
# # of images in lfw\Carol_Carmody\ : 1
# # of images in lfw\Carol_Moseley_Braun\ : 2
# # of images in lfw\Carol_Niedermayer\ : 1
# # of images in lfw\Carol_Williams\ : 1
# # of images in lfw\Carrie-Anne_Moss\ : 5
# # of images in lfw\Carroll_Weimer\ : 1
# # of images in lfw\Carson_Daly\ : 2
# # of images in lfw\Carson_Palmer\ : 4
# # of images in lfw\Casey_Crowder\ : 1
# # of images in lfw\Casey_Mears\ : 1
# # of images in lfw\Cassandra_Heise\ : 1
# # of images in lfw\Cass_Ballenger\ : 1
# # of images in lfw\Casy_Preslar\ : 1
# # of images in lfw\Cate_Blanchett\ : 4
# # of images in lfw\Catherine_Bell\ : 1
# # of images in lfw\Catherine_Deneuve\ : 5
# # of images in lfw\Catherine_Donkers\ : 1
# # of images in lfw\Catherine_Ndereba\ : 1
# # of images in lfw\Catherine_Woodard\ : 1
# # of images in lfw\Catherine_Zeta-Jones\ : 11
# # of images in lfw\Cathryn_Crawford\ : 1
# # of images in lfw\Cathy_Chisholm\ : 1
# # of images in lfw\Cathy_Cunningham\ : 1
# # of images in lfw\Cathy_Freeman\ : 2
# # of images in lfw\Catriona_Le_May_Doan\ : 1
# # of images in lfw\Cecile_de_France\ : 1
# # of images in lfw\Cecilia_Bolocco\ : 3
# # of images in lfw\Cecilia_Chang\ : 1
# # of images in lfw\Cecilia_Cheung\ : 1
# # of images in lfw\Cedric_Benson\ : 1
# # of images in lfw\Celia_Cruz\ : 1
# # of images in lfw\Celine_Dion\ : 8
# # of images in lfw\Celso_Amorim\ : 2
# # of images in lfw\Celso_Lafer\ : 1
# # of images in lfw\Cemil_Cicek\ : 1
# # of images in lfw\Cesar_Gaviria\ : 8
# # of images in lfw\Cesar_Maia\ : 2
# # of images in lfw\Chadha_Gurinder\ : 1
# # of images in lfw\Chakib_Khelil\ : 2
# # of images in lfw\Chance_Mock\ : 1
# # of images in lfw\Chanda_Rubin\ : 5
# # of images in lfw\Chandrika_Kumaratunga\ : 1
# # of images in lfw\Chang_Dae-whan\ : 2
# # of images in lfw\Chang_Jae_On\ : 1
# # of images in lfw\Chang_Saio-yue\ : 1
# # of images in lfw\Chang_Sang\ : 1
# # of images in lfw\Chang_Tso\ : 1
# # of images in lfw\Chante_Jawan_Mallard\ : 1
# # of images in lfw\Chan_Choi\ : 1
# # of images in lfw\Chan_Gailey\ : 3
# # of images in lfw\Chan_Ho_Park\ : 1
# # of images in lfw\Charla_Moye\ : 1
# # of images in lfw\Charlene_Barshefsky\ : 1
# # of images in lfw\Charles_Bell\ : 1
# # of images in lfw\Charles_Bronson\ : 3
# # of images in lfw\Charles_Chandler_IV\ : 1
# # of images in lfw\Charles_Cope\ : 1
# # of images in lfw\Charles_Grassley\ : 2
# # of images in lfw\Charles_Holzner\ : 1
# # of images in lfw\Charles_Ingram\ : 1
# # of images in lfw\Charles_Kartman\ : 2
# # of images in lfw\Charles_Lebois\ : 1
# # of images in lfw\Charles_Mathews\ : 2
# # of images in lfw\Charles_Moose\ : 13
# # of images in lfw\Charles_Pickering\ : 1
# # of images in lfw\Charles_Pouty\ : 1
# # of images in lfw\Charles_Richardson\ : 1
# # of images in lfw\Charles_Rogers\ : 1
# # of images in lfw\Charles_Schumer\ : 2
# # of images in lfw\Charles_Tannok\ : 1
# # of images in lfw\Charles_Taylor\ : 9
# # of images in lfw\Charley_Armey\ : 1
# # of images in lfw\Charlie_Coles\ : 1
# # of images in lfw\Charlie_Deane\ : 1
# # of images in lfw\Charlie_Garner\ : 1
# # of images in lfw\Charlie_Hunnam\ : 1
# # of images in lfw\Charlie_Sheen\ : 1
# # of images in lfw\Charlie_Williams\ : 1
# # of images in lfw\Charlie_Zaa\ : 2
# # of images in lfw\Charlize_Theron\ : 1
# # of images in lfw\Charlotte_Casiraghi\ : 1
# # of images in lfw\Charlotte_Chambers\ : 1
# # of images in lfw\Charlotte_Church\ : 1
# # of images in lfw\Charlotte_Rampling\ : 2
# # of images in lfw\Charlton_Heston\ : 6
# # of images in lfw\Charmaine_Crooks\ : 1
# # of images in lfw\Chawki_Armali\ : 1
# # of images in lfw\Cha_Yung-gu\ : 1
# # of images in lfw\Chea_Sophara\ : 1
# # of images in lfw\Chelsea_Clinton\ : 1
# # of images in lfw\Chen_Kaige\ : 1
# # of images in lfw\Chen_Liang_Yu\ : 2
# # of images in lfw\Chen_Shui-bian\ : 5
# # of images in lfw\Chen_Tsai-chin\ : 1
# # of images in lfw\Cherie_Blair\ : 4
# # of images in lfw\Cherry_Jones\ : 1
# # of images in lfw\Cheryl_Ford\ : 1
# # of images in lfw\Cheryl_Hines\ : 1
# # of images in lfw\Cheryl_James\ : 1
# # of images in lfw\Cheryl_Little\ : 1
# # of images in lfw\Cheryl_Tiegs\ : 1
# # of images in lfw\Chhouk_Rin\ : 1
# # of images in lfw\Chick_Hearn\ : 3
# # of images in lfw\Chin-Feng_Chen\ : 1
# # of images in lfw\Chin-Hui_Tsao\ : 1
# # of images in lfw\Chip_Burrus\ : 1
# # of images in lfw\Chip_Ganassi\ : 1
# # of images in lfw\Chip_Knight\ : 1
# # of images in lfw\Chistian_Stahl\ : 1
# # of images in lfw\Chita_Rivera\ : 2
# # of images in lfw\Chloe_Sevigny\ : 1
# # of images in lfw\Choi_Sung-hong\ : 5
# # of images in lfw\Choi_Yun-yong\ : 1
# # of images in lfw\Chok_Tong_Goh\ : 2
# # of images in lfw\Cho_Myung-kyun\ : 1
# # of images in lfw\Christiane_Wulff\ : 1
# # of images in lfw\Christian_Bale\ : 1
# # of images in lfw\Christian_Fittipaldi\ : 2
# # of images in lfw\Christian_Gimenez\ : 1
# # of images in lfw\Christian_Lacroix\ : 1
# # of images in lfw\Christian_Lirette\ : 1
# # of images in lfw\Christian_Longo\ : 3
# # of images in lfw\Christian_Malcolm\ : 1
# # of images in lfw\Christian_Olsson\ : 1
# # of images in lfw\Christian_Patino\ : 1
# # of images in lfw\Christian_Von_Wernich\ : 1
# # of images in lfw\Christian_Wulff\ : 2
# # of images in lfw\Christina_Aguilera\ : 4
# # of images in lfw\Christina_Sawaya\ : 1
# # of images in lfw\Christine_Arron\ : 1
# # of images in lfw\Christine_Baumgartner\ : 5
# # of images in lfw\Christine_Ebersole\ : 2
# # of images in lfw\Christine_Gregoire\ : 4
# # of images in lfw\Christine_Rau\ : 1
# # of images in lfw\Christine_Todd_Whitman\ : 6
# # of images in lfw\Christopher_Amolsch\ : 1
# # of images in lfw\Christopher_Conyers\ : 1
# # of images in lfw\Christopher_Matero\ : 1
# # of images in lfw\Christopher_Patten\ : 2
# # of images in lfw\Christopher_Reeve\ : 4
# # of images in lfw\Christopher_Russell\ : 1
# # of images in lfw\Christopher_Speer\ : 1
# # of images in lfw\Christopher_Walken\ : 4
# # of images in lfw\Christopher_Whittle\ : 1
# # of images in lfw\Christoph_Daum\ : 1
# # of images in lfw\Christy_Ferer\ : 1
# # of images in lfw\Christy_Turlington\ : 1
# # of images in lfw\Chris_Andrews\ : 1
# # of images in lfw\Chris_Bell\ : 2
# # of images in lfw\Chris_Byrd\ : 2
# # of images in lfw\Chris_Cirino\ : 1
# # of images in lfw\Chris_Claiborne\ : 1
# # of images in lfw\Chris_Columbus\ : 1
# # of images in lfw\Chris_Cookson\ : 1
# # of images in lfw\Chris_Cooper\ : 2
# # of images in lfw\Chris_Cornell\ : 1
# # of images in lfw\Chris_Crocker\ : 1
# # of images in lfw\Chris_Dodd\ : 1
# # of images in lfw\Chris_Forsyth\ : 1
# # of images in lfw\Chris_Gratton\ : 1
# # of images in lfw\Chris_Hernandez\ : 1
# # of images in lfw\Chris_Klein\ : 1
# # of images in lfw\Chris_Kolanas\ : 1
# # of images in lfw\Chris_Matthews\ : 1
# # of images in lfw\Chris_Moore\ : 1
# # of images in lfw\Chris_Neil\ : 1
# # of images in lfw\Chris_Noth\ : 1
# # of images in lfw\Chris_Penn\ : 1
# # of images in lfw\Chris_Pronger\ : 1
# # of images in lfw\Chris_Reitsma\ : 1
# # of images in lfw\Chris_Rock\ : 2
# # of images in lfw\Chris_Simon\ : 1
# # of images in lfw\Chris_Swecker\ : 1
# # of images in lfw\Chris_Terry\ : 1
# # of images in lfw\Chris_Thomas\ : 1
# # of images in lfw\Chris_Tucker\ : 2
# # of images in lfw\Chris_Whitney\ : 1
# # of images in lfw\Chuanyun_Li\ : 1
# # of images in lfw\Chuck_Amato\ : 2
# # of images in lfw\Chuck_Bednarik\ : 1
# # of images in lfw\Chuck_Eidson\ : 1
# # of images in lfw\Chuck_Finley\ : 1
# # of images in lfw\Chuck_Hagel\ : 1
# # of images in lfw\Chuck_Woolery\ : 1
# # of images in lfw\Chuck_Yeager\ : 2
# # of images in lfw\Chung_Mong-hun\ : 2
# # of images in lfw\Chung_Mong-joon\ : 2
# # of images in lfw\Chyung_Dai-chul\ : 1
# # of images in lfw\Ciaran_Hinds\ : 1
# # of images in lfw\Cindy_Crawford\ : 3
# # of images in lfw\Cindy_Klassen\ : 1
# # of images in lfw\Cindy_Margolis\ : 2
# # of images in lfw\Cindy_Moll\ : 1
# # of images in lfw\Cindy_Taylor\ : 1
# # of images in lfw\Cindy_Zagorski\ : 1
# # of images in lfw\Ciro_Gomes\ : 5
# # of images in lfw\Claire_Danes\ : 3
# # of images in lfw\Claire_De_Gryse\ : 1
# # of images in lfw\Claire_Hentzen\ : 2
# # of images in lfw\Claire_Leger\ : 2
# # of images in lfw\Claire_Tomalin\ : 1
# # of images in lfw\Clara_Harris\ : 5
# # of images in lfw\Clare_Latimer\ : 1
# # of images in lfw\Clare_Short\ : 4
# # of images in lfw\Clark_Randt\ : 1
# # of images in lfw\Claudette_Robinson\ : 1
# # of images in lfw\Claude_Jorda\ : 1
# # of images in lfw\Claudia_Cardinale\ : 1
# # of images in lfw\Claudia_Coslovich\ : 1
# # of images in lfw\Claudia_Pechstein\ : 5
# # of images in lfw\Claudia_Schiffer\ : 3
# # of images in lfw\Claudine_Farrell\ : 1
# # of images in lfw\Claudio_Abbado\ : 1
# # of images in lfw\Claudio_Lopez\ : 1
# # of images in lfw\Claudio_Ranieri\ : 1
# # of images in lfw\Clay_Aiken\ : 6
# # of images in lfw\Clay_Campbell\ : 1
# # of images in lfw\Clemente_de_la_Vega\ : 1
# # of images in lfw\Clifford_Etienne\ : 1
# # of images in lfw\Clifford_Robinson\ : 1
# # of images in lfw\Cliff_Ellis\ : 1
# # of images in lfw\Clint_Eastwood\ : 6
# # of images in lfw\Clint_Howard\ : 1
# # of images in lfw\Clint_Lamebear\ : 1
# # of images in lfw\Clive_Lloyd\ : 1
# # of images in lfw\Clive_Woodward\ : 1
# # of images in lfw\Coco_dEste\ : 1
# # of images in lfw\Coleen_Rowley\ : 1
# # of images in lfw\Cole_Chapman\ : 1
# # of images in lfw\Colin_Campbell\ : 1
# # of images in lfw\Colin_Cowie\ : 1
# # of images in lfw\Colin_Farrell\ : 9
# # of images in lfw\Colin_Jackson\ : 2
# # of images in lfw\Colin_Montgomerie\ : 5
# # of images in lfw\Colin_Phillips\ : 1
# # of images in lfw\Colin_Powell\ : 236
# # of images in lfw\Colin_Prescot\ : 1
# # of images in lfw\Colleen_Atwood\ : 1
# # of images in lfw\Colleen_Donovan\ : 1
# # of images in lfw\Colleen_Jones\ : 1
# # of images in lfw\Colleen_OClair\ : 1
# # of images in lfw\Colleen_Ryan\ : 1
# # of images in lfw\Collis_Temple_III\ : 1
# # of images in lfw\Columba_Bush\ : 1
# # of images in lfw\Compay_Segundo\ : 1
# # of images in lfw\Conan_OBrien\ : 4
# # of images in lfw\Conchita_Martinez\ : 3
# # of images in lfw\Condoleezza_Rice\ : 11
# # of images in lfw\Connie_Chung\ : 1
# # of images in lfw\Connie_Freydell\ : 1
# # of images in lfw\Conrad_Black\ : 1
# # of images in lfw\Constance_Marie\ : 3
# # of images in lfw\Cora_Cambell\ : 1
# # of images in lfw\Coretta_Scott_King\ : 3
# # of images in lfw\Corey_Maggette\ : 1
# # of images in lfw\Corinna_Harfouch\ : 1
# # of images in lfw\Corinne_Coman\ : 2
# # of images in lfw\Cori_Enghusen\ : 1
# # of images in lfw\Corliss_Williamson\ : 1
# # of images in lfw\Cosmo_Iacavazzi\ : 1
# # of images in lfw\Costas_Simitis\ : 6
# # of images in lfw\Courtney_Cox\ : 1
# # of images in lfw\Courtney_Love\ : 2
# # of images in lfw\Craig_Burley\ : 1
# # of images in lfw\Craig_David\ : 1
# # of images in lfw\Craig_Doblin\ : 1
# # of images in lfw\Craig_Fitzgibbon\ : 1
# # of images in lfw\Craig_MacTavish\ : 1
# # of images in lfw\Craig_Morgan\ : 1
# # of images in lfw\Craig_OClair\ : 1
# # of images in lfw\Craig_Wilson\ : 1
# # of images in lfw\Crandall_Bowles\ : 1
# # of images in lfw\Crispin_Glover\ : 1
# # of images in lfw\Cristiano_da_Matta\ : 1
# # of images in lfw\Cristian_Barros\ : 1
# # of images in lfw\Cristina_Fernandez\ : 2
# # of images in lfw\Cristina_Kirchner\ : 1
# # of images in lfw\Cristina_Saralegui\ : 2
# # of images in lfw\Cristina_Torrens_Valero\ : 1
# # of images in lfw\Cruz_Bustamante\ : 5
# # of images in lfw\Cuba_Gooding_Jr\ : 1
# # of images in lfw\Curtis_Joseph\ : 1
# # of images in lfw\Curtis_Rodriguez\ : 1
# # of images in lfw\Curtis_Strange\ : 1
# # of images in lfw\Curt_Weldon\ : 1
# # of images in lfw\Cyndi_Thompson\ : 2
# # of images in lfw\Cynthia_Nixon\ : 1
# # of images in lfw\Cynthia_Rowley\ : 1
# # of images in lfw\Dagmar_Dunlevy\ : 1
# # of images in lfw\Daisy_Fuentes\ : 4
# # of images in lfw\Dai_Bachtiar\ : 2
# # of images in lfw\Dai_Chul_Chyung\ : 1
# # of images in lfw\Daja_Bedanova\ : 1
# # of images in lfw\Dalai_Lama\ : 2
# # of images in lfw\Dale_Bosworth\ : 1
# # of images in lfw\Dale_Earnhardt\ : 1
# # of images in lfw\Dale_Earnhardt_Jr\ : 4
# # of images in lfw\Dalia_Rabin-Pelosoff\ : 1
# # of images in lfw\Damarius_Bilbo\ : 1
# # of images in lfw\Damon_Dash\ : 1
# # of images in lfw\Damon_Stoudamire\ : 1
# # of images in lfw\Damon_van_Dam\ : 2
# # of images in lfw\Dana_Vollmer\ : 1
# # of images in lfw\DAngelo_Jimenez\ : 1
# # of images in lfw\Daniela_Cicarelli\ : 1
# # of images in lfw\Daniela_Hantuchova\ : 2
# # of images in lfw\Daniele_Bergamin\ : 1
# # of images in lfw\Daniele_Hypolito\ : 1
# # of images in lfw\Daniele_Nardello\ : 1
# # of images in lfw\Danielle_Spencer\ : 1
# # of images in lfw\Daniell_Sunjata\ : 1
# # of images in lfw\Daniel_Barenboim\ : 1
# # of images in lfw\Daniel_Bruehl\ : 1
# # of images in lfw\Daniel_Chin\ : 1
# # of images in lfw\Daniel_Coats\ : 1
# # of images in lfw\Daniel_Comisso_Urdaneta\ : 1
# # of images in lfw\Daniel_Darnell\ : 1
# # of images in lfw\Daniel_Day-Lewis\ : 3
# # of images in lfw\Daniel_Kurtzer\ : 1
# # of images in lfw\Daniel_Montenegro\ : 1
# # of images in lfw\Daniel_Montgomery\ : 1
# # of images in lfw\Daniel_Ortega\ : 1
# # of images in lfw\Daniel_Osorno\ : 1
# # of images in lfw\Daniel_Patrick_Moynihan\ : 1
# # of images in lfw\Daniel_Pearl\ : 1
# # of images in lfw\Daniel_Radcliffe\ : 4
# # of images in lfw\Daniel_Rouse\ : 1
# # of images in lfw\Daniel_Scioli\ : 1
# # of images in lfw\Daniel_Zelman\ : 1
# # of images in lfw\Danis_Tanovic\ : 1
# # of images in lfw\Danny_Ainge\ : 1
# # of images in lfw\Danny_Avalon\ : 1
# # of images in lfw\Danny_Elfman\ : 1
# # of images in lfw\Danny_Glover\ : 1
# # of images in lfw\Danny_Green\ : 1
# # of images in lfw\Danny_Morgan\ : 1
# # of images in lfw\Dany_Heatley\ : 1
# # of images in lfw\Dan_Ackroyd\ : 1
# # of images in lfw\Dan_Bartlett\ : 1
# # of images in lfw\Dan_Boyle\ : 1
# # of images in lfw\Dan_Bylsma\ : 1
# # of images in lfw\Dan_Dickau\ : 1
# # of images in lfw\Dan_Duquette\ : 1
# # of images in lfw\Dan_Guerrero\ : 1
# # of images in lfw\Dan_Kellner\ : 1
# # of images in lfw\Dan_LaCoutre\ : 1
# # of images in lfw\Dan_Monson\ : 1
# # of images in lfw\Dan_Morales\ : 3
# # of images in lfw\Dan_Prinster\ : 1
# # of images in lfw\Dan_Quayle\ : 1
# # of images in lfw\Dan_Reeves\ : 1
# # of images in lfw\Dan_Snyder\ : 1
# # of images in lfw\Dan_Wheldon\ : 2
# # of images in lfw\Darcy_Regier\ : 1
# # of images in lfw\Darin_Erstad\ : 1
# # of images in lfw\Dario_Camuffo\ : 1
# # of images in lfw\Dario_Franchitti\ : 1
# # of images in lfw\Dariusz_Michalczewski\ : 1
# # of images in lfw\Darko_Milicic\ : 1
# # of images in lfw\Darla_Moore\ : 1
# # of images in lfw\Darlene_Garrettson\ : 1
# # of images in lfw\Darrell_Dickey\ : 1
# # of images in lfw\Darrell_Issa\ : 2
# # of images in lfw\Darrell_Porter\ : 2
# # of images in lfw\Darrell_Royal\ : 1
# # of images in lfw\Darren_Campel\ : 1
# # of images in lfw\Darren_Clarke\ : 2
# # of images in lfw\Darryl_McDaniels\ : 1
# # of images in lfw\Darryl_Stingley\ : 1
# # of images in lfw\Darvis_Patton\ : 1
# # of images in lfw\Daryl_Hannah\ : 2
# # of images in lfw\Daryl_Jones\ : 1
# # of images in lfw\Daryl_Parks\ : 1
# # of images in lfw\Daryl_Sabara\ : 1
# # of images in lfw\Daryl_Smith\ : 1
# # of images in lfw\Davey_Johnson\ : 1
# # of images in lfw\Dave_Barr\ : 1
# # of images in lfw\Dave_Campo\ : 3
# # of images in lfw\Dave_Johnson\ : 1
# # of images in lfw\Dave_Lewis\ : 1
# # of images in lfw\Dave_Matthews\ : 1
# # of images in lfw\Dave_McGinnis\ : 1
# # of images in lfw\Dave_McNally\ : 1
# # of images in lfw\Dave_McNealey\ : 1
# # of images in lfw\Dave_Odom\ : 1
# # of images in lfw\Dave_Potter\ : 1
# # of images in lfw\Dave_Ragone\ : 1
# # of images in lfw\Dave_Robertson\ : 1
# # of images in lfw\Dave_Tucker\ : 1
# # of images in lfw\Dave_Wannstedt\ : 1
# # of images in lfw\Dave_Williams\ : 1
# # of images in lfw\David_Alpay\ : 1
# # of images in lfw\David_Anderson\ : 5
# # of images in lfw\David_Arquette\ : 1
# # of images in lfw\David_Ballantyne\ : 1
# # of images in lfw\David_Beckham\ : 31
# # of images in lfw\David_Bell\ : 2
# # of images in lfw\David_Bisbal\ : 1
# # of images in lfw\David_Blaine\ : 1
# # of images in lfw\David_Bowie\ : 1
# # of images in lfw\David_Braley\ : 1
# # of images in lfw\David_Brent\ : 1
# # of images in lfw\David_Brinkley\ : 1
# # of images in lfw\David_Brown\ : 1
# # of images in lfw\David_Canary\ : 1
# # of images in lfw\David_Caraway\ : 2
# # of images in lfw\David_Carradine\ : 1
# # of images in lfw\David_Caruso\ : 3
# # of images in lfw\David_Chase\ : 1
# # of images in lfw\David_Collenette\ : 1
# # of images in lfw\David_Coulthard\ : 2
# # of images in lfw\David_Dewayne_Williams\ : 1
# # of images in lfw\David_Dewhurst\ : 1
# # of images in lfw\David_Dodge\ : 2
# # of images in lfw\David_Donohue\ : 1
# # of images in lfw\David_Dorfman\ : 1
# # of images in lfw\David_Duke\ : 1
# # of images in lfw\David_Duval\ : 1
# # of images in lfw\David_Eldon\ : 1
# # of images in lfw\David_Gest\ : 1
# # of images in lfw\David_Glenn\ : 1
# # of images in lfw\David_Hannay\ : 1
# # of images in lfw\David_Hanson\ : 1
# # of images in lfw\David_Hasselhoff\ : 1
# # of images in lfw\David_Heyman\ : 2
# # of images in lfw\David_Heymann\ : 5
# # of images in lfw\David_Hilt\ : 1
# # of images in lfw\David_Ho\ : 1
# # of images in lfw\David_Howard\ : 1
# # of images in lfw\David_Hyde_Pierce\ : 4
# # of images in lfw\David_Kelley\ : 2
# # of images in lfw\David_Kelly\ : 1
# # of images in lfw\David_Leahy\ : 2
# ...
# # of images in lfw\Monica_Vergara\ : 1
# # of images in lfw\Monique_Ferreira\ : 1
# # of images in lfw\Monique_Gagnon-Tremblay\ : 1
# # of images in lfw\Monique_Garbrecht-Enfeldt\ : 3
# # of images in lfw\Monte_Kiffin\ : 1
# # of images in lfw\Moon-So-ri\ : 1
# # of images in lfw\Morgan_Fairchild\ : 1
# # of images in lfw\Morgan_Freeman\ : 2
# # of images in lfw\Morgan_Hentzen\ : 1
# # of images in lfw\Morris_Dees\ : 1
# # of images in lfw\Morris_Watts\ : 1
# # of images in lfw\Moshe_Katsav\ : 4
# # of images in lfw\Mother_Teresa\ : 1
# # of images in lfw\Mo_Elleithee\ : 1
# # of images in lfw\Mstislav_Rostropovich\ : 1
# # of images in lfw\Ms_Dynamite\ : 1
# # of images in lfw\Muammar_Gaddafi\ : 2
# # of images in lfw\Muffet_McGraw\ : 1
# # of images in lfw\Mufti_Mohammad_Syed\ : 1
# # of images in lfw\Muhammad_Ali\ : 10
# # of images in lfw\Muhammad_Ibrahim_Bilal\ : 1
# # of images in lfw\Muhammad_Saeed_al-Sahhaf\ : 5
# # of images in lfw\Mukesh_Ambani\ : 3
# # of images in lfw\Mukhtar_Alytnbayev\ : 1
# # of images in lfw\Munir_Akram\ : 2
# # of images in lfw\Muwafak_al-Ani\ : 1
# # of images in lfw\Myung_Yang\ : 1
# # of images in lfw\Nabil_Shaath\ : 3
# # of images in lfw\Nadia_Forte\ : 1
# # of images in lfw\Nadia_Petrova\ : 5
# # of images in lfw\Nadine_Vinzens\ : 2
# # of images in lfw\Najib_al-Salhi\ : 1
# # of images in lfw\Naji_Sabri\ : 8
# # of images in lfw\Namuddu_Florence\ : 1
# # of images in lfw\Nancy_Demme\ : 2
# # of images in lfw\Nancy_Greenlaw\ : 1
# # of images in lfw\Nancy_Humbert\ : 1
# # of images in lfw\Nancy_Kerrigan\ : 1
# # of images in lfw\Nancy_Pelosi\ : 15
# # of images in lfw\Nancy_Powell\ : 1
# # of images in lfw\Nancy_Reagan\ : 2
# # of images in lfw\Nancy_Sinatra\ : 2
# # of images in lfw\Nancy_Smith\ : 1
# # of images in lfw\Nanni_Moretti\ : 2
# # of images in lfw\Nan_Wang\ : 4
# # of images in lfw\Naomi_Bronstein\ : 1
# # of images in lfw\Naomi_Campbell\ : 2
# # of images in lfw\Naomi_Hayashi\ : 1
# # of images in lfw\Naomi_Watts\ : 22
# # of images in lfw\Naoto_Kan\ : 4
# # of images in lfw\Narayan_Singh_Pun\ : 1
# # of images in lfw\Narendra_Modi\ : 1
# # of images in lfw\Nasser_al-Kidwa\ : 2
# # of images in lfw\Nastassia_Kinski\ : 2
# # of images in lfw\Nastia_Liukin\ : 1
# # of images in lfw\Natalia_Dmitrieva\ : 1
# # of images in lfw\Natalia_Motuziuk\ : 1
# # of images in lfw\Natalia_Verbeke\ : 1
# # of images in lfw\Natalia_Vodonova\ : 1
# # of images in lfw\Natalie_Cole\ : 3
# # of images in lfw\Natalie_Coughlin\ : 6
# # of images in lfw\Natalie_Imbruglia\ : 1
# # of images in lfw\Natalie_Juniardi\ : 1
# # of images in lfw\Natalie_Maines\ : 5
# # of images in lfw\Natalie_Stewart\ : 1
# # of images in lfw\Natalie_Williams\ : 1
# # of images in lfw\Natalya_Sazanovich\ : 1
# # of images in lfw\Natanaela_Barnova\ : 1
# # of images in lfw\Natasa_Micic\ : 1
# # of images in lfw\Natasha_Henstridge\ : 1
# # of images in lfw\Natasha_Lyonne\ : 1
# # of images in lfw\Natasha_McElhone\ : 3
# # of images in lfw\Nate_Blackwell\ : 1
# # of images in lfw\Nate_Huffman\ : 1
# # of images in lfw\Nate_Hybl\ : 1
# # of images in lfw\Nathalia_Gillot\ : 1
# # of images in lfw\Nathalie_Baye\ : 4
# # of images in lfw\Nathalie_Dechy\ : 1
# # of images in lfw\Nathalie_Gagnon\ : 1
# # of images in lfw\Nathan_Doudney\ : 1
# # of images in lfw\Nathan_Lane\ : 2
# # of images in lfw\Nathan_Powell\ : 1
# # of images in lfw\Nathan_Smith\ : 1
# # of images in lfw\Nathirah_Hussein\ : 1
# # of images in lfw\Nawabzada_Nasrullah_Khan\ : 1
# # of images in lfw\Na_Na_Keum\ : 1
# # of images in lfw\Nebojsa_Pavkovic\ : 2
# # of images in lfw\Neil_Goldman\ : 1
# # of images in lfw\Neil_Moritz\ : 1
# # of images in lfw\Nelson_Acosta\ : 1
# # of images in lfw\Nelson_Mandela\ : 4
# # of images in lfw\Nelson_Shanks\ : 1
# # of images in lfw\Neri_Marcore\ : 2
# # of images in lfw\Nestor_Gonzalez\ : 1
# # of images in lfw\Nestor_Kirchner\ : 37
# # of images in lfw\Nestor_Santillan\ : 1
# # of images in lfw\Newton_Carlton_Slawson\ : 1
# # of images in lfw\Newt_Gingrich\ : 1
# # of images in lfw\Niall_Connolly\ : 1
# # of images in lfw\Nia_Vardalos\ : 5
# # of images in lfw\Nicanor_Duarte_Frutos\ : 11
# # of images in lfw\Nicholas_Byron\ : 2
# # of images in lfw\Nicholas_Tse\ : 2
# # of images in lfw\Nicholoas_DiMarzio\ : 1
# # of images in lfw\Nicklas_Lidstrom\ : 1
# # of images in lfw\Nick_Cassavetes\ : 1
# # of images in lfw\Nick_Markakis\ : 1
# # of images in lfw\Nick_Nolte\ : 5
# # of images in lfw\Nick_Price\ : 1
# # of images in lfw\Nick_Rahall\ : 1
# # of images in lfw\Nick_Reilly\ : 1
# # of images in lfw\Nick_Rimando\ : 1
# # of images in lfw\Nick_Turner\ : 1
# # of images in lfw\Nicolas_Cage\ : 4
# # of images in lfw\Nicolas_Escude\ : 2
# # of images in lfw\Nicolas_Eyzaguirre\ : 1
# # of images in lfw\Nicolas_Kiefer\ : 1
# # of images in lfw\Nicolas_Lapentti\ : 2
# # of images in lfw\Nicolas_Latorre\ : 1
# # of images in lfw\Nicolas_Macrozonaris\ : 1
# # of images in lfw\Nicolas_Massu\ : 1
# # of images in lfw\Nicolas_Sarkozy\ : 1
# # of images in lfw\Nicola_Bono\ : 1
# # of images in lfw\Nicola_Wells\ : 1
# # of images in lfw\Nicole\ : 1
# # of images in lfw\Nicoletta_Braschi\ : 1
# # of images in lfw\Nicole_Hiltz\ : 1
# # of images in lfw\Nicole_Kidman\ : 19
# # of images in lfw\Nicole_Parker\ : 1
# # of images in lfw\Nida_Blanca\ : 1
# # of images in lfw\Nigel_Redden\ : 1
# # of images in lfw\Nikki_Cascone\ : 1
# # of images in lfw\Nikki_McKibbin\ : 1
# # of images in lfw\Nikki_Reed\ : 2
# # of images in lfw\Nikki_Teasley\ : 1
# # of images in lfw\Nikolay_Davydenko\ : 1
# # of images in lfw\Nila_Ferran\ : 1
# # of images in lfw\Nina_Jacobson\ : 1
# # of images in lfw\Nina_Pecari\ : 1
# # of images in lfw\Nino_DAngelo\ : 1
# # of images in lfw\Nizar_Trabelsi\ : 1
# # of images in lfw\Noah_Wyle\ : 3
# # of images in lfw\Nobuyuki_Idei\ : 1
# # of images in lfw\Noelle_Bush\ : 4
# # of images in lfw\Noel_Forgeard\ : 1
# # of images in lfw\Noel_Niell\ : 1
# # of images in lfw\Noer_Moeis\ : 1
# # of images in lfw\Noer_Muis\ : 1
# # of images in lfw\Nona_Gaye\ : 1
# # of images in lfw\Nong_Duc_Manh\ : 1
# # of images in lfw\Noor_Mohammed\ : 1
# # of images in lfw\Norah_Jones\ : 15
# # of images in lfw\Nora_Bendijo\ : 2
# # of images in lfw\Nora_Ephron\ : 1
# # of images in lfw\Norbert_van_Heyst\ : 1
# # of images in lfw\Norio_Ohga\ : 1
# # of images in lfw\Normand_Legault\ : 1
# # of images in lfw\Norman_Jewison\ : 2
# # of images in lfw\Norman_Mailer\ : 1
# # of images in lfw\Norman_Mineta\ : 1
# # of images in lfw\Norm_Coleman\ : 7
# # of images in lfw\Norm_Macdonald\ : 1
# # of images in lfw\Norodom_Chakrapong\ : 1
# # of images in lfw\Norodom_Sihanouk\ : 3
# # of images in lfw\Nova_Esther_Guthrie\ : 1
# # of images in lfw\Nuon_Chea\ : 1
# # of images in lfw\Nursultan_Nazarbayev\ : 2
# # of images in lfw\Nur_Jaafar\ : 1
# # of images in lfw\Octavio_Lara\ : 1
# # of images in lfw\Odai_Hussein\ : 1
# # of images in lfw\Odilia_Collazo\ : 1
# # of images in lfw\OJ_Simpson\ : 2
# # of images in lfw\Oleg_Romantsev\ : 1
# # of images in lfw\Oleksandr_Moroz\ : 2
# # of images in lfw\Olene_Walker\ : 1
# # of images in lfw\Olesya_Bonabarenko\ : 2
# # of images in lfw\Olivera_Labus\ : 1
# # of images in lfw\Oliver_Neuville\ : 1
# # of images in lfw\Oliver_Phelps\ : 1
# # of images in lfw\Oliver_Stone\ : 1
# # of images in lfw\Olivia_Newton-John\ : 2
# # of images in lfw\Olivier_Boulay\ : 1
# # of images in lfw\Olivier_Rochus\ : 1
# # of images in lfw\Olympia_Dukakis\ : 1
# # of images in lfw\Omar_el-Heib\ : 1
# # of images in lfw\Omar_Khan_Sharif\ : 1
# # of images in lfw\Omar_Sharif\ : 4
# # of images in lfw\Omar_Vizquel\ : 1
# # of images in lfw\Ontario_Lett\ : 1
# # of images in lfw\Oprah_Winfrey\ : 4
# # of images in lfw\Oracene_Williams\ : 1
# # of images in lfw\Orlando_Bloom\ : 3
# # of images in lfw\Ornella_Muti\ : 1
# # of images in lfw\Orrin_Hatch\ : 2
# # of images in lfw\Osama_Al_Baz\ : 1
# # of images in lfw\Osama_bin_Laden\ : 4
# # of images in lfw\Oscar_Bolanos\ : 1
# # of images in lfw\Oscar_De_La_Hoya\ : 7
# # of images in lfw\Oscar_de_la_Renta\ : 1
# # of images in lfw\Oscar_DLeon\ : 1
# # of images in lfw\Oscar_Elias_Biscet\ : 2
# # of images in lfw\Osmond_Smith\ : 1
# # of images in lfw\Osrat_Iosef\ : 1
# # of images in lfw\Oswaldo_Paya\ : 5
# # of images in lfw\Oswald_Gruebel\ : 1
# # of images in lfw\Otto_Reich\ : 1
# # of images in lfw\Otto_Schily\ : 1
# # of images in lfw\Owen_Nolan\ : 1
# # of images in lfw\Owen_Wilson\ : 2
# # of images in lfw\Oxana_Fedorova\ : 4
# # of images in lfw\Ozzie_Smith\ : 1
# # of images in lfw\Ozzy_Osbourne\ : 3
# # of images in lfw\Pablo_Khulental\ : 1
# # of images in lfw\Pablo_Latras\ : 1
# # of images in lfw\Paddy_Long\ : 1
# # of images in lfw\Paddy_Torsney\ : 1
# # of images in lfw\Padraig_Harrington\ : 4
# # of images in lfw\Paek_Nam_Sun\ : 1
# # of images in lfw\Paige_Fitzgerald\ : 1
# # of images in lfw\Pak_Gil_Yon\ : 1
# # of images in lfw\Pamela_Anderson\ : 5
# # of images in lfw\Pamela_Melroy\ : 1
# # of images in lfw\Paola_Espinoza\ : 1
# # of images in lfw\Paradorn_Srichaphan\ : 10
# # of images in lfw\Paris_Hilton\ : 2
# # of images in lfw\Park_Jie-won\ : 1
# # of images in lfw\Park_Jung_Sung\ : 1
# # of images in lfw\Park_Na-kyong\ : 1
# # of images in lfw\Parris_Glendening\ : 2
# # of images in lfw\Parthiv_Patel\ : 1
# # of images in lfw\Pascal_Affi_Nguessan\ : 1
# # of images in lfw\Pascal_Lamy\ : 2
# # of images in lfw\Pascal_Quignard\ : 3
# # of images in lfw\Pascal_Rheaume\ : 1
# # of images in lfw\Patrice_Chereau\ : 2
# # of images in lfw\Patricia_Clarkson\ : 4
# # of images in lfw\Patricia_Garone\ : 1
# # of images in lfw\Patricia_Hearst\ : 1
# # of images in lfw\Patricia_Heaton\ : 2
# # of images in lfw\Patricia_Johnson\ : 1
# # of images in lfw\Patricia_Medina\ : 1
# # of images in lfw\Patricia_Phillips\ : 1
# # of images in lfw\Patricia_Russo\ : 1
# # of images in lfw\Patricia_Wartusch\ : 1
# # of images in lfw\Patrick_Bourrat\ : 1
# # of images in lfw\Patrick_Clawsen\ : 1
# # of images in lfw\Patrick_Coleman\ : 1
# # of images in lfw\Patrick_Dennehy\ : 1
# # of images in lfw\Patrick_Eaves\ : 1
# # of images in lfw\Patrick_Ewing\ : 2
# # of images in lfw\Patrick_Kron\ : 1
# # of images in lfw\Patrick_Leahy\ : 2
# # of images in lfw\Patrick_McEnroe\ : 2
# # of images in lfw\Patrick_Rafter\ : 1
# # of images in lfw\Patrick_Roy\ : 2
# # of images in lfw\Patrick_Stewart\ : 2
# # of images in lfw\Patrik_Kristiansson\ : 1
# # of images in lfw\Patsy_Hardy\ : 1
# # of images in lfw\Patsy_Kensit\ : 1
# # of images in lfw\Patsy_Mink\ : 1
# # of images in lfw\Patti_Balgojevich\ : 1
# # of images in lfw\Patti_Labelle\ : 3
# # of images in lfw\Patti_Lank\ : 1
# # of images in lfw\Patti_Smith\ : 1
# # of images in lfw\Patty_Duke\ : 1
# # of images in lfw\Patty_Schnyder\ : 4
# # of images in lfw\Patty_Sheehan\ : 1
# # of images in lfw\Pat_Burns\ : 2
# # of images in lfw\Pat_Cox\ : 2
# # of images in lfw\Pat_DAmuro\ : 1
# # of images in lfw\Pat_Riley\ : 1
# # of images in lfw\Pat_Rochester\ : 1
# # of images in lfw\Pat_Summerall\ : 1
# # of images in lfw\Pat_Summitt\ : 1
# # of images in lfw\Pat_Wharton\ : 1
# # of images in lfw\Paul-Henri_Mathieu\ : 3
# # of images in lfw\Paula_Abdul\ : 1
# # of images in lfw\Paula_Dobriansky\ : 1
# # of images in lfw\Paula_Locke\ : 1
# # of images in lfw\Paula_Prentiss\ : 1
# # of images in lfw\Paula_Radcliffe\ : 6
# # of images in lfw\Paula_Zahn\ : 2
# # of images in lfw\Pauley_Perrette\ : 1
# # of images in lfw\Paulie_Ayala\ : 1
# # of images in lfw\Paulina_Rodriguez_Davila\ : 1
# # of images in lfw\Pauline_Landers\ : 1
# # of images in lfw\Pauline_Phillips\ : 1
# # of images in lfw\Paulo_Cesar_Pinheiro\ : 2
# # of images in lfw\Paul_Bettany\ : 1
# # of images in lfw\Paul_Brandt\ : 1
# # of images in lfw\Paul_Bremer\ : 20
# # of images in lfw\Paul_Burrell\ : 11
# # of images in lfw\Paul_Byrd\ : 2
# # of images in lfw\Paul_Celluci\ : 1
# # of images in lfw\Paul_Cerjan\ : 1
# # of images in lfw\Paul_Clark\ : 1
# # of images in lfw\Paul_Coppin\ : 2
# # of images in lfw\Paul_Crake\ : 1
# # of images in lfw\Paul_Desmarais\ : 1
# # of images in lfw\Paul_Ebert\ : 1
# # of images in lfw\Paul_Farley\ : 1
# # of images in lfw\Paul_Gannon\ : 1
# # of images in lfw\Paul_Gascoigne\ : 3
# # of images in lfw\Paul_Greengrass\ : 1
# # of images in lfw\Paul_Henderson\ : 1
# # of images in lfw\Paul_Hogan\ : 2
# # of images in lfw\Paul_Johnson\ : 1
# # of images in lfw\Paul_Kagame\ : 2
# # of images in lfw\Paul_Kariya\ : 1
# # of images in lfw\Paul_Kelleher\ : 1
# # of images in lfw\Paul_Krueger\ : 1
# # of images in lfw\Paul_LeClerc\ : 1
# # of images in lfw\Paul_Li_Calsi\ : 1
# # of images in lfw\Paul_Lockhart\ : 1
# # of images in lfw\Paul_Lo_Duca\ : 1
# # of images in lfw\Paul_Luvera\ : 1
# # of images in lfw\Paul_Martin\ : 8
# # of images in lfw\Paul_McCartney\ : 7
# # of images in lfw\Paul_McNulty\ : 2
# # of images in lfw\Paul_Michael_Daniels\ : 1
# # of images in lfw\Paul_Murphy\ : 1
# # of images in lfw\Paul_Newman\ : 1
# # of images in lfw\Paul_ONeill\ : 9
# # of images in lfw\Paul_Otellini\ : 1
# # of images in lfw\Paul_Patton\ : 2
# # of images in lfw\Paul_Pierce\ : 2
# # of images in lfw\Paul_Reiser\ : 1
# # of images in lfw\Paul_Sarbanes\ : 3
# # of images in lfw\Paul_Schrader\ : 1
# # of images in lfw\Paul_Shanley\ : 3
# # of images in lfw\Paul_Tagliabue\ : 4
# # of images in lfw\Paul_Tracy\ : 1
# # of images in lfw\Paul_Vathis\ : 1
# # of images in lfw\Paul_Walker\ : 1
# # of images in lfw\Paul_Wals\ : 1
# # of images in lfw\Paul_Wellstone\ : 3
# # of images in lfw\Paul_William_Hurley\ : 2
# # of images in lfw\Paul_Wilson\ : 1
# # of images in lfw\Paul_Wolfowitz\ : 10
# # of images in lfw\Paul_Wollnough\ : 1
# # of images in lfw\Pa_Kou_Hang\ : 1
# # of images in lfw\Pedro_Almodovar\ : 7
# # of images in lfw\Pedro_Alvarez\ : 1
# # of images in lfw\Pedro_Duque\ : 1
# # of images in lfw\Pedro_Mahecha\ : 1
# # of images in lfw\Pedro_Malan\ : 5
# # of images in lfw\Pedro_Martinez\ : 1
# # of images in lfw\Pedro_Pauleta\ : 1
# # of images in lfw\Pedro_Solbes\ : 4
# # of images in lfw\Pedro_Velasquez\ : 1
# # of images in lfw\Peggy_McGuinness\ : 1
# # of images in lfw\Pele\ : 1
# # of images in lfw\Penelope_Ann_Miller\ : 2
# # of images in lfw\Penelope_Cruz\ : 3
# # of images in lfw\Penelope_Taylor\ : 1
# # of images in lfw\Penny_Dupuie\ : 1
# # of images in lfw\Penny_Lancaster\ : 1
# # of images in lfw\Percy_Gibson\ : 1
# # of images in lfw\Peri_Gilpin\ : 1
# # of images in lfw\Pernilla_Bjorn\ : 1
# # of images in lfw\Perri_Shaw\ : 1
# # of images in lfw\Perry_Compton\ : 1
# # of images in lfw\Perry_Farrell\ : 1
# # of images in lfw\Perry_Gibbs\ : 1
# # of images in lfw\Pervez_Musharraf\ : 18
# # of images in lfw\Peter_Ahearn\ : 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-281-cb1563e3e9e3> in <module>
#       9     fold_df=pd.DataFrame.from_dict(dist_dict,orient='index').reset_index()
#      10     fold_df['folder']=folder_nm
# ---> 11     dist_df=pd.concat([dist_df,fold_df],axis=0,ignore_index=True, sort=False)
#      12 dist_df.rename(columns={0:'num_images','index':'category'},inplace=True)
#      13 print(dist_df.groupby('folder')['num_images'].sum())
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     494                 mgrs_indexers.append((obj._data, indexers))
#     495
# --> 496             new_data = concatenate_block_managers(
#     497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2019             )
#    2020         else:
# -> 2021             b = make_block(
#    2022                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    2023                 placement=placement,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3025
#    3026
# -> 3027 def make_block(values, placement, klass=None, ndim=None, dtype=None):
#    3028     # Ensure that we don't allow PandasArray / PandasDtype in internals.
#    3029     # For now, blocks should be backed by ndarrays when possible.
#
# KeyboardInterrupt:

# %%
human_dist_df=images_perfolderhuman('lfw/*/')
human_dist_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-280-a848786fb1a2> in <module>
# ----> 1 human_dist_df=images_perfolderhuman('lfw/*/')
#       2 human_dist_df
#
# <ipython-input-279-6c9f2160406e> in images_perfolderhuman(main_path)
#      10         fold_df=pd.DataFrame.from_dict(dist_dict,orient='index').reset_index()
#      11         fold_df['folder']=folder_nm
# ---> 12         dist_df=pd.concat([dist_df,fold_df],axis=0,ignore_index=True, sort=False)
#      13  #   dist_df.rename(columns={0:'num_images','index':'category'},inplace=True)
#      14 #     print(dist_df.groupby('folder')['num_images'].sum())
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     269     ValueError: Indexes have overlapping values: ['a']
#     270     """
# --> 271     op = _Concatenator(
#     272         objs,
#     273         axis=axis,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     358
#     359             # consolidate
# --> 360             obj._consolidate(inplace=True)
#     361             ndims.add(obj.ndim)
#     362
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in _consolidate(self, inplace)
#    5363         inplace = validate_bool_kwarg(inplace, "inplace")
#    5364         if inplace:
# -> 5365             self._consolidate_inplace()
#    5366         else:
#    5367             f = lambda: self._data.consolidate()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5345             self._data = self._data.consolidate()
#    5346
# -> 5347         self._protect_consolidate(f)
#    5348
#    5349     def _consolidate(self, inplace: bool_t = False):
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5334         """
#    5335         blocks_before = len(self._data.blocks)
# -> 5336         result = f()
#    5337         if len(self._data.blocks) != blocks_before:
#    5338             self._clear_item_cache()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in f()
#    5343
#    5344         def f():
# -> 5345             self._data = self._data.consolidate()
#    5346
#    5347         self._protect_consolidate(f)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# KeyboardInterrupt:

# %%
totalbyhuman=human_dist_df.groupby("folder").num_images.sum() 
print(totalbyhuman)
totalbyhuman.hist()
# Out:
# folder
# AJ_Cook               1
# AJ_Lamas              1
# Aaron_Eckhart         1
# Aaron_Guiel           1
# Aaron_Patterson       1
#                      ..
# Zorica_Radovic        1
# Zulfiqar_Ahmed        1
# Zumrati_Juma          1
# Zurab_Tsereteli       1
# Zydrunas_Ilgauskas    1
# Name: num_images, Length: 5749, dtype: int64

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# In this section, we use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.
#
# OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.  In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[10])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.

# %% [markdown]
# __Answer:__
# (You can print out your results and/or write your percentages in this cell)

# %%
from tqdm import tqdm
human_files_short = human_files[:100]
dog_files_short = dog_files[:100]
#-#-# Do NOT modify the code above this line. #-#-#

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
# run the function face_detector to check number of True values. 

#define first row
k=0
number_human_face=0
number_dog_face=0
#create loop to run all rows, since human and dog are using 100 images 
for k in tqdm(range(len(human_files_short))):
    if face_detector(human_files_short[k]) == True:
        number_human_face+=1
    if face_detector(dog_files_short[k]) == True:
        number_dog_face+=1
    k+=1    
percent_human=(number_human_face/len(human_files_short))*100
print('human faces ',percent_human, "%")
percent_dog=(number_dog_face/len(dog_files_short))*100
print('dog faces ',percent_dog, "%")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:36<00:00,  2.77it/s]
# human faces  96.0 %
# dog faces  18.0 %

# %% [markdown]
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Test performance of another face detection algorithm.
### Feel free to use as many code cells as needed.

# extract pre-trained face detector
face_cascade2 = cv2.CascadeClassifier('lbpcascades/lbpcascade_frontalface.xml')

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector2(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces2 = face_cascade2.detectMultiScale(gray)
    return len(faces2) > 0

# %%
#define first row
k=0
number_human_face=0
number_dog_face=0
#create loop to run all rows, since human and dog are using 100 images 
for k in tqdm(range(len(human_files_short))):
    if face_detector2(human_files_short[k]):
        number_human_face+=1
    if face_detector2(dog_files_short[k]):
        number_dog_face+=1
    k+=1    
percent_human=(number_human_face/len(human_files_short))*100
print('human faces ',percent_human, "%")
percent_dog=(number_dog_face/len(dog_files_short))*100
print('dog faces ',percent_dog, "%")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:13<00:00,  7.50it/s]
# human faces  92.0 %
# dog faces  31.0 %

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a [pre-trained model](http://pytorch.org/docs/master/torchvision/models.html) to detect dogs in images.
#
# ### Obtain Pre-trained VGG-16 Model
#
# The code cell below downloads the VGG-16 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
import torch
import torchvision.models as models

# define VGG16 model
VGG16 = models.vgg16(pretrained=True)

# check if CUDA is available
use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
if use_cuda:
    VGG16 = VGG16.cuda()

# %%
VGG16
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Given an image, this pre-trained VGG-16 model returns a prediction (derived from the 1000 possible categories in ImageNet) for the object that is contained in the image.

# %% [markdown]
# ### (IMPLEMENTATION) Making Predictions with a Pre-trained Model
#
# In the next code cell, you will write a function that accepts a path to an image (such as `'dogImages/train/001.Affenpinscher/Affenpinscher_00001.jpg'`) as input and returns the index corresponding to the ImageNet class that is predicted by the pre-trained VGG-16 model.  The output should always be an integer between 0 and 999, inclusive.
#
# Before writing the function, make sure that you take the time to learn  how to appropriately pre-process tensors for pre-trained models in the [PyTorch documentation](http://pytorch.org/docs/stable/torchvision/models.html).

# %%
import io
from PIL import Image
import torchvision.transforms as transforms

# Set PIL to be tolerant of image files that are truncated.
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

import numpy as np

train_on_gpu = torch.cuda.is_available()
    #Check if available to train on gpu
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
 
    
def VGG16_predict(img_path):
    '''
    Use pre-trained VGG-16 model to obtain index corresponding to 
    predicted ImageNet class for image at specified path   
    Args:
        img_path: path to an image        
    Returns:
        Index corresponding to VGG-16 model's prediction
    '''    
    #open image file 
    input_image = Image.open(img_path)
    #preprocess function defined which transform the image so that images are converted to tensors, 
    #all consistent size and normalised accordingly
    preprocess = transforms.Compose([transforms.Resize(256),transforms.CenterCrop(224),transforms.ToTensor(),
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    input_tensor = preprocess(input_image) #create input tensor by feeding input image with the preprocess function.
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    with torch.no_grad(): #no back propogation altering the gradients. Keeping the model attributes the same. 
        output = VGG16(input_batch) #Tensor of shape 1000, with confidence scores over Imagenet's 1000 classes
    # print(output)
    # The output has unnormalized scores. To get probabilities, you can run a softmax on it.
    # print(torch.nn.functional.softmax(output[0], dim=0))           

    #extract the index with the maximum value in the second dimension which has 0:999 classes of dogs
    xx,predicted = output.max(dim=1)    #xx is the value, predicted is the class index

    #print('Pre-trained model predicts an index of', predicted.item())
    return predicted.item()
# Out:
# CUDA is not available.  Training on CPU ...

# %% [markdown]
# ### (IMPLEMENTATION) Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained VGG-16 model, we need only check if the pre-trained model predicts an index between 151 and 268 (inclusive).
#
# Use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    ## TODO: Complete the function.
    # check prediction of the image
    index_predict=VGG16_predict(img_path)
    
#     #check if output index is between 151 and 268. If yes, True, False for No. 
     
    if index_predict >151 and index_predict<268:
        return True
    else:
        return False

# %%
#just to test it out
dog_detector(human_files[0])
# Out:
# False

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 2:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?

# %% [markdown]
# __Answer:__
#
# detect a dog in human_files 0.0 %, detect a dog in dog_files 94.0 %

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
nbr_human=0
nbr_dog=0
i=0
for i in tqdm(range(len(human_files_short))):
    if dog_detector(human_files_short[i]):
        nbr_human+=1
    if dog_detector(dog_files_short[i]):
        nbr_dog+=1
    i+=1
     
percent_human=(nbr_human/len(human_files_short))*100
print('detect a dog in human_files',percent_human, "%")
percent_dog=(nbr_dog/len(dog_files_short))*100
print('detect a dog in dog_files',percent_dog, "%")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [02:23<00:00,  1.44s/it]
# detect a dog in human_files 0.0 %
# detect a dog in dog_files 94.0 %

# %% [markdown]
# We suggest VGG-16 as a potential network to detect dog images in your algorithm, but you are free to explore other pre-trained networks (such as [Inception-v3](http://pytorch.org/docs/master/torchvision/models.html#inception-v3), [ResNet-50](http://pytorch.org/docs/master/torchvision/models.html#id3), etc).  Please use the code cell below to test other pre-trained PyTorch models.  If you decide to pursue this _optional_ task, report performance on `human_files_short` and `dog_files_short`.

# %%
### (Optional) 
### TODO: Report the performance of another pre-trained network.
### test the Inceptionv3 model

import torch
import torchvision.models as models

# define inception_v3 model
inceptionv3 = models.inception_v3(pretrained=True)
inceptionv3.eval()
# check if CUDA is available
#use_cuda = torch.cuda.is_available()

# move model to GPU if CUDA is available
#if use_cuda:
#    inceptionv3 = inceptionv3.cuda()

# %%
train_on_gpu = torch.cuda.is_available()
    #Check if available to train on gpu
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
 
    
def inceptionv3_predict(img_path):
  
    #open image file 
    input_image = Image.open(img_path)
    #preprocess function defined which transform the image so that images are converted to tensors, 
    #all consistent size and normalised accordingly
    preprocess = transforms.Compose([transforms.Resize(299),transforms.CenterCrop(299),transforms.ToTensor(),
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    input_tensor = preprocess(input_image)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    with torch.no_grad(): #no back propogation altering the gradients. Keeping the model attributes the same. 
        output = inceptionv3(input_batch)        

    #extract the index with the maximum value in the second dimension which has 0:999 classes of dogs
    xx,predicted = output.max(dim=1)

    return predicted.item()

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector2(img_path):
    ## TODO: Complete the function.
    # check prediction of the image
    index_predict=inceptionv3_predict(img_path)
    
#     #check if output index is between 151 and 268. If yes, True, False for No. 
     
    if index_predict >151 and index_predict<268:
        return True
    else:
        return False

# %%
x=Image.open(dog_files_short[50])
preprocess = transforms.Compose([transforms.Resize(299),transforms.CenterCrop(299),transforms.ToTensor(),
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])
input_tensor=preprocess(x)
input_batch = input_tensor.unsqueeze(0)
with torch.no_grad(): #no back propogation altering the gradients. Keeping the model attributes the same. 
    output = inceptionv3(input_batch)

# %%
output

# %%
dog_detector2(human_files_short[50])

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
nbr_human=0
nbr_dog=0
i=0
for i in tqdm(range(len(human_files_short))):
    if dog_detector2(human_files_short[i]):
        nbr_human+=1
    if dog_detector2(dog_files_short[i]):
        nbr_dog+=1
    i+=1
     
percent_human=(nbr_human/len(human_files_short))*100
print('detect a dog in human_files',percent_human, "%")
percent_dog=(nbr_dog/len(dog_files_short))*100
print('detect a dog in dog_files',percent_dog, "%")

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 10%.  In Step 4 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have trouble distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).  You may find [this documentation on custom datasets](http://pytorch.org/docs/stable/torchvision/datasets.html) to be a useful resource.  If you are interested in augmenting your training and/or validation data, check out the wide variety of [transforms](http://pytorch.org/docs/stable/torchvision/transforms.html?highlight=transform)!

# %%
import os
from random import shuffle
from __future__ import print_function, division
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision import transforms, utils

### TODO: Write data loaders for training, validation, and test sets
# define training, test and validation data directories, if on udacity: use /data/....
train_dir = 'dogImages/train'
valid_dir = 'dogImages/valid'
test_dir = 'dogImages/test'

standard_normalization = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                              std=[0.229, 0.224, 0.225])
#define transform criterias
train_transforms = transforms.Compose([transforms.Resize(size=256),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.RandomRotation(10),
                                       transforms.CenterCrop(224),
                                       transforms.ToTensor(),
                                       standard_normalization])
validTest_transforms = transforms.Compose([transforms.Resize(size=256),
                                           transforms.CenterCrop(224),
                                           transforms.ToTensor(),
                                           standard_normalization])

#create the transformed images into tensors datasets
datatrain = datasets.ImageFolder(train_dir, train_transforms)
datavalid = datasets.ImageFolder(valid_dir, validTest_transforms)
datatest = datasets.ImageFolder(test_dir, validTest_transforms)

#prepare data loaders for each dataset which will be used to feed into the model for batch training, test and validation.
#training loader
train_loader = torch.utils.data.DataLoader(datatrain,batch_size=32,shuffle=True,num_workers=0)
#test loader
valid_loader = torch.utils.data.DataLoader(datavalid,batch_size=32,shuffle=True,num_workers=0)
# test loader
test_loader = torch.utils.data.DataLoader(datatest,batch_size=32,shuffle=True,num_workers=0)

# %% [markdown]
# **Question 3:** Describe your chosen procedure for preprocessing the data.
# - How does your code resize the images (by cropping, stretching, etc)?  What size did you pick for the input tensor, and why?
# - Did you decide to augment the dataset?  If so, how (through translations, flips, rotations, etc)?  If not, why not?

# %% [markdown]
# **Answer**:The images are resized to 256 pixels and centre cropped 224 pixels. If I crop before resize, I might not caputre all the key feature, thus it is crucial to resize and crop after.
#
# Looking from the sample images on dogimages. The photo of the dogs have their heads being captured in the image and sometimes their body or head is nor orientated right up thus I used a randomrotation. Sometimes the body and head is oiriented from left to right instead of right to left, thus a horizontal random flip is used.
#
# Image augmentation will create randomness to the dataset created, prevents overfitting, thus giving better overall performance for prediction. Since validation and test data will be used for validation and test check, no randomhorizontal flip or rotation was used.

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  Use the template in the code cell below.

# %%
#examples, need to deep dive in detals all each parameter mean and the arguments
import torch
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):      #initialise class Net and nn.Module as super initialise the parent class too
        super(Net, self).__init__()
        #define neural network parameters for layers
        # 1 input image with 3 input channel, 16 output channels, 3x3 square convolution
        ## convolutional layer (sees 32x32x3 image tensor)
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1) # 1 layer of padding with 3 by 3 filter to retain information in the image. 
        self.conv2 = nn.Conv2d(16, 32, 3,padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3,padding=1)
        self.pool = nn.MaxPool2d(2, 2)          # max pooling layer
        self.fc1 = nn.Linear(64* 28* 28, 1024) #to test
        # dropout layer (p=0.25) #doest matter where its placed as initializing all the different layers, sequence are all done on the forward function
        self.dropout = nn.Dropout(0.25)
        self.fc2 = nn.Linear(1024,133)        
# to define each layer how they interact with each other, input x produce output x for each input/output layers defined.
    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2)) #max pooling with a filter of 2 by 2. 
        x=self.dropout(x)
        # If the size is a square you can only specify a single number
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x=self.dropout(x)
        x = F.max_pool2d(F.relu(self.conv3(x)), 2)
        x=self.dropout(x)
#       print(x.shape) to check the shape
        x=x.view(-1,64*28*28)     #-1 suggests "any size". So it could be 1, 12, 92, 15295...etc
        x=self.dropout(x)
        x = F.relu(self.fc1(x))
        x=self.dropout(x)            # feed through dropout layer. 
        x = self.fc2(x)
        return x

#-#-# You do NOT have to modify the code below this line. #-#-#
model_scratch = Net()   # instantiate the CNN
if use_cuda:  # move tensors to GPU if CUDA is available
    model_scratch.cuda()    
print(model_scratch)

# %% [markdown]
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.

# %% [markdown]
# __Answer:__ Output classification would be 133 different breed of dogs thus 133 for final linear neural network output. Input channels is 3 as for every image there is R,B,G images fed at a time unless its greyscale images. Thus nn.Conv2d(3,6,3) for singe input 6 outputs and filter/kernel of 3*3. The smaller filter size of 3* at the first layer would be useful to extract all the features present in the picture.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/stable/optim.html).  Save the chosen loss function as `criterion_scratch`, and the optimizer as `optimizer_scratch` below.

# %%
import torch.optim as optim
### TODO: select loss function
criterion_scratch = nn.CrossEntropyLoss()
# optimizer optimizes the weights to improve and reduce the loss, ca try optim.Adam, best to use decaying learning rate
### TODO: select optimizer #using torch optimizer of SGD (stoichastic gradient descent) for the model's parameters with a learning rate of 0.01. 
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr=0.001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_scratch.pt'`.

# %%
from tqdm import tqdm
              
# the following import is required for training to be robust to truncated images called transfer learning.
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

def train(n_epochs, loaders1, loaders2, model, optimizer, criterion, use_cuda, save_path):
    """returns trained model"""
    # initialize tracker for minimum validation loss
    old_valid_loss = np.Inf 
    
    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0
        
        ###################
        # train the model #
        ###################
        model.train
        
         # Iterate over data.
#         for inputs, labels in dataloaders[phase]:
        for batch_idx, (data, target) in tqdm(enumerate(loaders1)):
        #data,target in iter(train_loader):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
        
            ## find the loss and update the model parameters accordingly
            #difference between output and target is the loss
            # zero the parameter gradients after each batch data
            optimizer.zero_grad()
            
# forward
            #predicted outputs
            outputs = model(data)
          #  _, preds = torch.max(outputs, 1)
            #batch loss is calculated using criterion
            loss = criterion(outputs, target)

# backward + optimize only in training phase
            #back propogate the loss
            loss.backward()
            # adjust the weights
            optimizer.step()
            
            #what does this mean?
            #train_loss += ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            ## update the total of train loss after each batch
            train_loss += loss.item()*data.size(0)
            
        ######################    
        # validate the model #
        ######################
        model.eval()
        #data is input, output is prediction, 
        for batch_idx, (data, target) in tqdm(enumerate(loaders2)):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
                
           # forward pass: compute predicted outputs by passing input data to the model
            outputs = model(data)
            
            #batch loss is calculated using criterion
            loss = criterion(outputs, target)
            
             ## update the total of validation loss after each batch
            valid_loss += loss.item()*data.size(0)
            
        #calculate the average train_loss and valid_loss
        train_loss=train_loss/len(train_loader)
        valid_loss=valid_loss/len(valid_loader)
            
        # print training/validation statistics 
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch, 
            train_loss,
            valid_loss
            ))
        
        ## TODO: save the model if validation loss has decreased
        #new valid loss if its less than the old valid loss, save the model and display the changes from old to new.
        if valid_loss<old_valid_loss:
            #save model with valid loss
            torch.save(model.state_dict(),save_path)
            
            print('Validation loss has decreased ({:.6f} ======> {:.6f}). Saving model ....'.format
                  (old_valid_loss,valid_loss))
            #the retained valid loss will be the new value. 
            old_valid_loss=valid_loss
              
    # return trained model
    return model

# %%
# train the model
#def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
model_scratch = train(15, train_loader, valid_loader, model_scratch, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch.pt')

# %%
# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('model_scratch.pt'))

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    for batch_idx, (data, target) in enumerate(loaders):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss 
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)
            
    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function    
test(test_loader, model_scratch, criterion_scratch, use_cuda)

# %% [markdown]
# <a id='step4'></a>
# ## Step 3b: Create a better model architect
#
# Accuracy level less than 10%, observed overfitting occured as training loss reduce but validation loss increase. Create a better model architect which is more simplified with less layers, less cycles,

# %%
class Net2(nn.Module):

    def __init__(self):
        #initialise class Net and nn.Module as super initialise the parent class too
        super(Net2, self).__init__()
        #define neural network parameters for layers
        # 1 input image with 3 channel, 16 output channels, 3x3 square convolution
        # kernel
        ## convolutional layer (sees 32x32x3 image tensor)
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1) # 1 layer of padding with 3 by 3 filter to retain information in the image. 
        self.pool = nn.MaxPool2d(2, 2)
        
        self.dropout = nn.Dropout(0.25)
        self.conv2 = nn.Conv2d(16, 32, 3,padding=1)
        self.pool = nn.MaxPool2d(2, 2)
    
        self.dropout = nn.Dropout(0.25)
        self.conv3 = nn.Conv2d(32, 64, 3,padding=1)
        # max pooling layer
        
        self.pool = nn.MaxPool2d(2, 2)
        # an affine operation: y = Wx + b
        self.dropout = nn.Dropout(0.25)
        self.fc1 = nn.Linear(64* 28* 28, 1024) #to test
        
#        self.fc1 = nn.Linear(128* 28* 28, 500)  # 6*6 from image dimension
        # dropout layer (p=0.25) #doest matter where its placed as initializing all the different layers, sequence are all done on the forward function

        self.fc2 = nn.Linear(1024,133)

        
# to define each layer how they interact with each other, input x produce output x for each input/output layers defined.
    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2)) #max pooling with a filter of 2 by 2. 
        x=self.dropout(x)
        # If the size is a square you can only specify a single number
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x=self.dropout(x)
        x = F.max_pool2d(F.relu(self.conv3(x)), 2)
        x=self.dropout(x)
        # flatten
 #       x=x.flatten(1)
#        print(x.shape)
        #-1 suggests "any size". So it could be 1, 12, 92, 15295...etc
        x=x.view(-1,64*28*28)
        # feed through dropout layer. 
        x=self.dropout(x)
#        x = x.view(x.size(0), -1)

        x = F.relu(self.fc1(x))
        x=self.dropout(x)
        x = self.fc2(x)
        return x

    
    
#-#-# You do NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch2 = Net2()

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch2.cuda()
    
print(model_scratch2)

# %%
# train the model2
#def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):
model_scratch2 = train(20, train_loader, valid_loader, model_scratch2, optimizer_scratch, 
                      criterion_scratch, use_cuda, 'model_scratch2.pt')

# %%
# call test function    
test(test_loader, model_scratch2, criterion_scratch, use_cuda)

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# ### (IMPLEMENTATION) Specify Data Loaders for the Dog Dataset
#
# Use the code cell below to write three separate [data loaders](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader) for the training, validation, and test datasets of dog images (located at `dogImages/train`, `dogImages/valid`, and `dogImages/test`, respectively).
#
# If you like, **you are welcome to use the same data loaders from the previous step**, when you created a CNN from scratch.

# %%
## TODO: Specify data loaders
train_loader = torch.utils.data.DataLoader(datatrain,
                                          batch_size=32,
                                          shuffle=True,
                                          num_workers=0)
#test loader
valid_loader = torch.utils.data.DataLoader(datavalid,
                                          batch_size=32,
                                          shuffle=True,
                                          num_workers=0)
# test loader
test_loader = torch.utils.data.DataLoader(datatest,
                                          batch_size=32,
                                          shuffle=True,
                                          num_workers=0)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Use transfer learning to create a CNN to classify dog breed.  Use the code cell below, and save your initialized model as the variable `model_transfer`.

# %%
import torchvision.models as models
import torch.nn as nn

## TODO: Specify model architecture 
#import the VGG16 model
model_transfer=models.vgg16(pretrained=True)

# %%
model_transfer

# %%
from collections import OrderedDict

# replace the fully connected layer classifier to match the number of dog classifications required. 
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(25088, 4096)),
                          ('relu', nn.ReLU()),
                          ('fc2', nn.Linear(4096, 133)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))

# ensures we don’t update the weights from the pre-trained model.
for param in model_transfer.parameters():
    param.requires_grad = False

# Unfreeze training for fully connected (fc) layers   
# for param in model_transfer.fc.parameters():
#     param.requires_grad = True

#map new classifier to the model
model_transfer.classifier=classifier

if use_cuda:
    model_transfer = model_transfer.cuda()

# %%
model_transfer

# %% [markdown]
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# __Answer:__
# 1. utilised the same data loaders as before.
# 2. created a new object defined as the transfer model. The transfer model is using the VGG16 model.
# 3. The classifier of the model is altered to match the intended dog breed output we require.
# 4. The weights of this pretrained model is not altered in the convolution network.
# 5. Define the classifier of the model to be the classifier we created.

# %% [markdown]
# ### (IMPLEMENTATION) Specify Loss Function and Optimizer
#
# Use the next code cell to specify a [loss function](http://pytorch.org/docs/master/nn.html#loss-functions) and [optimizer](http://pytorch.org/docs/master/optim.html).  Save the chosen loss function as `criterion_transfer`, and the optimizer as `optimizer_transfer` below.

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.Adam(model_transfer.classifier.parameters(), lr=0.0001)

# %% [markdown]
# ### (IMPLEMENTATION) Train and Validate the Model
#
# Train and validate your model in the code cell below.  [Save the final model parameters](http://pytorch.org/docs/master/notes/serialization.html) at filepath `'model_transfer.pt'`.

# %%
# train the model
#def train(n_epochs, loaders1, loaders2, model, optimizer, criterion, use_cuda, save_path)
# train(n_epochs, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')
model_transfer =  train(10,train_loader ,valid_loader ,
                        model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')

# %%
# load the model that got the best validation accuracy (uncomment the line below)
model_transfer.load_state_dict(torch.load('model_transfer.pt'))

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60%.

# %%
test(test_loader, model_transfer, criterion_transfer, use_cuda)

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan hound`, etc) that is predicted by your model.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.
import glob
# list of class names by index, i.e. a name can be accessed like class_names[0]
class_names = [item[4:].replace("_", " ") for item in datatrain.classes]
#raw_class= [item[4:].replace("_", " ") for item in datatrain.classes]
def predict_breed_transfer(img_path):
    
    
    #open image file 
    input_image = Image.open(img_path)
    #preprocess function defined which transform the image so that images are converted to tensors, 
    #all consistent size and normalised accordingly
    preprocess = transforms.Compose([transforms.Resize(256),transforms.CenterCrop(224),transforms.ToTensor(),
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    input_tensor = preprocess(input_image)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    with torch.no_grad(): #no back propogation altering the gradients. Keeping the model attributes the same. 
        output = model_transfer(input_batch)  
        
    #The max value in all outcome probability for all output channels is the predicted class. 
    #extract the index with the maximum value in the second dimension which has 0:999 classes of dogs
    xx,predict = output.max(dim=1)
    
    return datatrain.classes[predict]

# %%
#if dog or human detected
def display_image(img_path):
    my_list=[]
    #predictedimage=datatrain.classes(raw_class)
    raw_class=predict_breed_transfer(img_path)
    pred_dir=train_dir+"/"+raw_class+"/*.*"

    class_names =raw_class.replace("_"," ")[4:]

    #prepare random sample data from the predicted breed
    predpath=glob.glob(pred_dir)
    for file in random.sample(list(predpath),1):
      #  print(file)
        a=Image.open(file)
        my_list.append(a)
        
    #open and display input image
    image = Image.open(img_path) #img_path
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.title("Input Image")

    # display the random sample image from the predicted breed
    plt.subplot(1,2,2)
    plt.imshow(my_list[0])
    plt.title(label=f"Predicted breed:{class_names}")

    plt.show()

# %%
# Try out the function
for image in random.sample(list(human_files_short), 4): 
 #   predicted_breed = predict_breed_transfer(image)
    
    display_image(image)

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 4 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def run_app(img_path):
    ## handle cases for a human face, dog, and neither
# if a human face is present, print( "human face present")
    if face_detector(img_path) == True:
        print(" human face present!....This human looks like a ....")
# and then predict what dog breed does the human face looks like
        display_image(img_path)  

# check if a dog is present
# predict dog breed it look like    
    elif dog_detector2(img_path) == True:
        print(" dog is present!...This dog looks like a...")
        display_image(img_path) 
        
 #   we dont find a human or dog in the photo. please try again to reinput the image. No output prediction avaialble.      
    else:
        print("cant find a human or a dog in the photo, please try again")
        image = Image.open(img_path) #img_path
        plt.title("Input Image")
        plt.imshow(image)
        plt.show()

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that _you_ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.

# %% [markdown]
# __Answer:__ (Three possible points for improvement)
# 1. THe dog breed prediction was only 79% accuracy, still room for improvement in terms of the algorithm with more training, altering the layers, size of the network as well as learning rate and type of criterion and optimizer.
# 2. Dog breed prediction for human images are not very applicable but there is visible common features.
# 3. Cleanup code to make it more modular.
# 4. Benchmark different models and parameters used.
# 5. Able to handle multiple dog or human in an image.
# 6. Return the top 4 classes predicted and their probabilities.
# 7. Implement this in an API such as AWS.

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

## suggested code, below
for file in np.hstack((human_files[:3], dog_files[:3])):
    run_app(file)

# %%
run_app("fahilindog.jpg")
print()
run_app("fahilindog2.jpg")
print()
run_app("fahilindog3.jpg")
print()
run_app("fahilin.jpg")
print()
run_app("fahilin2.jpg")

# %%
run_app("nicoledog.jpg")
print()
run_app("peiyee3.jpg")
print()
run_app("chung2.jpg")
print()
run_app("pompom.jpg")
print()
run_app("booboo.jpg")
print()
run_app("mina.jpg")
